# %% [markdown]
# # Predict 20 Timesteps, Electrode 5

# %%
# Autoreload
# %load_ext autoreload
# %autoreload 2

# %%
# Imports
import numpy as np
import json
import pandas as pd
import numpy as np
import time
import string
from matplotlib import pyplot as plt
import tensorflow as tf
import sys
sys.path.append('../../../')
from brain2brain import utils, generators, models
# %matplotlib inline

# TF
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# TCN
from brain2brain.tcn import TCN
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Flatten, GRU, LSTM, RepeatVector, TimeDistributed

from scipy.stats import pearsonr

# %%
train_paths = utils.get_file_paths("/home/tmarcu/brain2brain/brain2brain/train_676_bin_norm_2.txt")
val_paths = utils.get_file_paths("/home/tmarcu/brain2brain/brain2brain/val_676_bin_norm_2.txt")
total_electrode_count = utils.get_file_shape(train_paths[0])[1]
# Electrodes
electrode_count = 1
electrode = 5
lookback = 100
pred_length = 20
# Training Generator
train_generator = generators.FGenerator(file_paths=train_paths,
                                        lookback=lookback,
                                        length=pred_length,
                                        delay=0,
                                        batch_size=1024,
                                        sample_period=1,
                                        electrodes=[electrode],
                                        electrode_output_ix=electrode,
                                        shuffle=True,
                                        teacher_forcing=True)
# Validation Generator
val_generator = generators.FGenerator(file_paths=val_paths,
                                        lookback=lookback,
                                        length=pred_length,
                                        delay=0,
                                        batch_size=1024,
                                        sample_period=1,
                                        electrodes=[electrode],
                                        electrode_output_ix=electrode,
                                        shuffle=False,
                                        teacher_forcing=True)
# Out:
# (5429, 114)

# %%
hidden_units = 256
dropout = 0.05
train, inf_encoder_model, inf_decoder_model = models.define_enc_dec_model_jeddy_o2o(hidden_units, dropout)

# %%
train.compile(optimizer='adam', loss='mae')
train.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 1)]    0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None, 1)]    0
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 256), (None, 264192      input_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, None, 256),  264192      input_2[0][0]
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 1)      257         lstm_1[0][0]
# ==================================================================================================
# Total params: 528,641
# Trainable params: 528,641
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
callback_list = [
#         EarlyStopping(
#             monitor="val_loss",
#             patience=2,
#             mode="min"
#         )
]
history = train.fit_generator(generator=train_generator,
                              callbacks=callback_list,
                              epochs=100,
                              validation_data=val_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-6-230407738530>:11: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 12 steps, validate for 4 steps
# Epoch 1/100
# 12/12 [==============================] - 29s 2s/step - loss: 0.5775 - val_loss: 0.5369
# Epoch 2/100
# 12/12 [==============================] - 3s 260ms/step - loss: 0.5348 - val_loss: 0.5172
# Epoch 3/100
# 12/12 [==============================] - 3s 255ms/step - loss: 0.5225 - val_loss: 0.5089
# Epoch 4/100
# 12/12 [==============================] - 3s 255ms/step - loss: 0.5144 - val_loss: 0.5021
# Epoch 5/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.5065 - val_loss: 0.4935
# Epoch 6/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.5022 - val_loss: 0.4897
# Epoch 7/100
# 12/12 [==============================] - 3s 257ms/step - loss: 0.4982 - val_loss: 0.4861
# Epoch 8/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4967 - val_loss: 0.4858
# Epoch 9/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4957 - val_loss: 0.4850
# Epoch 10/100
# 12/12 [==============================] - 3s 255ms/step - loss: 0.4954 - val_loss: 0.4858
# Epoch 11/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4953 - val_loss: 0.4855
# Epoch 12/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4956 - val_loss: 0.4853
# Epoch 13/100
# 12/12 [==============================] - 3s 257ms/step - loss: 0.4957 - val_loss: 0.4853
# Epoch 14/100
# 12/12 [==============================] - 3s 273ms/step - loss: 0.4953 - val_loss: 0.4841
# Epoch 15/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4949 - val_loss: 0.4838
# Epoch 16/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4946 - val_loss: 0.4840
# Epoch 17/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4943 - val_loss: 0.4843
# Epoch 18/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4948 - val_loss: 0.4838
# Epoch 19/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4941 - val_loss: 0.4834
# Epoch 20/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4946 - val_loss: 0.4828
# Epoch 21/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4938 - val_loss: 0.4830
# Epoch 22/100
# 12/12 [==============================] - 3s 252ms/step - loss: 0.4941 - val_loss: 0.4835
# Epoch 23/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4942 - val_loss: 0.4835
# Epoch 24/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4938 - val_loss: 0.4825
# Epoch 25/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4932 - val_loss: 0.4828
# Epoch 26/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4940 - val_loss: 0.4825
# Epoch 27/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4936 - val_loss: 0.4833
# Epoch 28/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4937 - val_loss: 0.4829
# Epoch 29/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4934 - val_loss: 0.4828
# Epoch 30/100
# 12/12 [==============================] - 3s 256ms/step - loss: 0.4935 - val_loss: 0.4825
# Epoch 31/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4930 - val_loss: 0.4825
# Epoch 32/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4936 - val_loss: 0.4823
# Epoch 33/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4927 - val_loss: 0.4822
# Epoch 34/100
# 12/12 [==============================] - 3s 252ms/step - loss: 0.4923 - val_loss: 0.4826
# Epoch 35/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4925 - val_loss: 0.4826
# Epoch 36/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4932 - val_loss: 0.4828
# Epoch 37/100
# 12/12 [==============================] - 3s 258ms/step - loss: 0.4924 - val_loss: 0.4815
# Epoch 38/100
# 12/12 [==============================] - 3s 258ms/step - loss: 0.4923 - val_loss: 0.4821
# Epoch 39/100
# 12/12 [==============================] - 3s 260ms/step - loss: 0.4923 - val_loss: 0.4821
# Epoch 40/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4922 - val_loss: 0.4823
# Epoch 41/100
# 12/12 [==============================] - 3s 257ms/step - loss: 0.4921 - val_loss: 0.4815
# Epoch 42/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4921 - val_loss: 0.4820
# Epoch 43/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4922 - val_loss: 0.4815
# Epoch 44/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4922 - val_loss: 0.4816
# Epoch 45/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4916 - val_loss: 0.4822
# Epoch 46/100
# 12/12 [==============================] - 3s 258ms/step - loss: 0.4920 - val_loss: 0.4819
# Epoch 47/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4915 - val_loss: 0.4813
# Epoch 48/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4921 - val_loss: 0.4818
# Epoch 49/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4917 - val_loss: 0.4816
# Epoch 50/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4916 - val_loss: 0.4819
# Epoch 51/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4921 - val_loss: 0.4817
# Epoch 52/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4920 - val_loss: 0.4810
# Epoch 53/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4916 - val_loss: 0.4818
# Epoch 54/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4918 - val_loss: 0.4817
# Epoch 55/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4915 - val_loss: 0.4823
# Epoch 56/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4921 - val_loss: 0.4818
# Epoch 57/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4913 - val_loss: 0.4815
# Epoch 58/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4908 - val_loss: 0.4811
# Epoch 59/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4905 - val_loss: 0.4816
# Epoch 60/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4909 - val_loss: 0.4811
# Epoch 61/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4909 - val_loss: 0.4810
# Epoch 62/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4912 - val_loss: 0.4813
# Epoch 63/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4915 - val_loss: 0.4813
# Epoch 64/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4912 - val_loss: 0.4812
# Epoch 65/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4904 - val_loss: 0.4813
# Epoch 66/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4910 - val_loss: 0.4815
# Epoch 67/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4911 - val_loss: 0.4812
# Epoch 68/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4917 - val_loss: 0.4821
# Epoch 69/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4911 - val_loss: 0.4818
# Epoch 70/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4908 - val_loss: 0.4810
# Epoch 71/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4901 - val_loss: 0.4810
# Epoch 72/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4902 - val_loss: 0.4810
# Epoch 73/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4898 - val_loss: 0.4812
# Epoch 74/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4906 - val_loss: 0.4814
# Epoch 75/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4904 - val_loss: 0.4814
# Epoch 76/100
# 12/12 [==============================] - 3s 255ms/step - loss: 0.4901 - val_loss: 0.4811
# Epoch 77/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4899 - val_loss: 0.4814
# Epoch 78/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4898 - val_loss: 0.4812
# Epoch 79/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4896 - val_loss: 0.4810
# Epoch 80/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4897 - val_loss: 0.4815
# Epoch 81/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4899 - val_loss: 0.4813
# Epoch 82/100
# 12/12 [==============================] - 3s 254ms/step - loss: 0.4903 - val_loss: 0.4814
# Epoch 83/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4894 - val_loss: 0.4811
# Epoch 84/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4894 - val_loss: 0.4815
# Epoch 85/100
# 12/12 [==============================] - 3s 275ms/step - loss: 0.4893 - val_loss: 0.4810
# Epoch 86/100
# 12/12 [==============================] - 3s 258ms/step - loss: 0.4893 - val_loss: 0.4820
# Epoch 87/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4891 - val_loss: 0.4818
# Epoch 88/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4891 - val_loss: 0.4818
# Epoch 89/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4895 - val_loss: 0.4821
# Epoch 90/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4890 - val_loss: 0.4812
# Epoch 91/100
# 12/12 [==============================] - 3s 255ms/step - loss: 0.4886 - val_loss: 0.4817
# Epoch 92/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4888 - val_loss: 0.4820
# Epoch 93/100
# 12/12 [==============================] - 3s 252ms/step - loss: 0.4885 - val_loss: 0.4816
# Epoch 94/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4879 - val_loss: 0.4817
# Epoch 95/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4881 - val_loss: 0.4818
# Epoch 96/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4882 - val_loss: 0.4818
# Epoch 97/100
# 12/12 [==============================] - 3s 253ms/step - loss: 0.4879 - val_loss: 0.4823
# Epoch 98/100
# 12/12 [==============================] - 3s 255ms/step - loss: 0.4875 - val_loss: 0.4820
# Epoch 99/100
# 12/12 [==============================] - 3s 255ms/step - loss: 0.4878 - val_loss: 0.4816
# Epoch 100/100
# 12/12 [==============================] - 3s 255ms/step - loss: 0.4876 - val_loss: 0.4825

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error Loss')
plt.title('Loss Over Time')
plt.legend(['Train','Valid'])

# %%
from tensorflow.keras.models import model_from_json

file_name = "models/enc_dec_o2o_100_20_train"
# serialize model to JSON
model_json = train.to_json()
with open(f"{file_name}.json", "w") as json_file:
    json_file.write(model_json)
train.save_weights(f"{file_name}.h5")

file_name = "models/enc_dec_o2o_100_20_enc"
# serialize model to JSON
model_json = train.to_json()
with open(f"{file_name}.json", "w") as json_file:
    json_file.write(model_json)
inf_encoder_model.save_weights(f"{file_name}.h5")

file_name = "models/enc_dec_o2o_100_20_dec"
# serialize model to JSON
model_json = train.to_json()
with open(f"{file_name}.json", "w") as json_file:
    json_file.write(model_json)
inf_decoder_model.save_weights(f"{file_name}.h5")

# %%
from tensorflow.keras.models import model_from_json

file_name = "models/enc_dec_o2o_100_20_train"
# load json and create model
json_file = open(f'{file_name}.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
train = model_from_json(loaded_model_json)
# load weights into new model
train.load_weights(f"{file_name}.h5")
print("Loaded model from disk")

file_name = "models/enc_dec_o2o_100_20_enc"
# load json and create model
json_file = open(f'{file_name}.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
inf_encoder_model = model_from_json(loaded_model_json)
# load weights into new model
inf_encoder_model.load_weights(f"{file_name}.h5")
print("Loaded model from disk")

file_name = "models/enc_dec_o2o_100_20_dec"
# load json and create model
json_file = open(f'{file_name}.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
inf_decoder_model = model_from_json(loaded_model_json)
# load weights into new model
inf_decoder_model.load_weights(f"{file_name}.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
def predict_and_plot(encoder_input_data, decoder_target_data, sample_ix, pred_steps: int, enc_tail_len=100):
    encode_series = encoder_input_data[0][sample_ix:sample_ix+1,:,:] 
    pred_series = models.decode_sequence_o2o(inf_encoder_model,
                                             inf_decoder_model, 
                                             input_seq=encode_series,
                                             pred_steps=pred_steps)
    encode_series = encode_series.reshape(-1,1)
    pred_series = pred_series.reshape(-1,1)   
    target_series = decoder_target_data[sample_ix,:,:1].reshape(-1,1)
    encode_series_tail = np.concatenate([encode_series[-enc_tail_len:],target_series[:1]])
    x_encode = encode_series_tail.shape[0]
    r, p = pearsonr(pred_series.reshape(-1), target_series.reshape(-1))
    mae = np.mean(np.abs(pred_series.reshape(-1) - target_series.reshape(-1)))
    print(f"Correlation: {r}. P: {p}. mae: {mae}")
    plt.figure(figsize=(10,6))   
    
    plt.plot(range(1,x_encode+1),encode_series_tail)
    plt.plot(range(x_encode,x_encode+pred_steps),target_series,color='orange')
    plt.plot(range(x_encode,x_encode+pred_steps),pred_series,color='teal',linestyle='--')
    
    plt.title('Encoder Series Tail of Length %d, Target Series, and Predictions' % enc_tail_len)
    plt.legend(['Encoding Series','Target Series','Predictions'])

# %%
val_batch = val_generator[0]

# %%
len(val_batch[0][0])
# Out:
# 1024

# %%
predict_and_plot(val_batch[0], val_batch[1], sample_ix=0, pred_steps=20)
# Out:
# Correlation: 0.2287682403726649. P: 0.331969291428963. mae: 0.5663804736724118

# %%
def get_corr_mae(encoder_input_data, decoder_target_data, sample_ix, pred_steps: int,
                 enc_tail_len=100, verbose=True):
    encode_series = encoder_input_data[0][sample_ix:sample_ix+1,:,:] 
    pred_series = models.decode_sequence_o2o(inf_encoder_model,
                                             inf_decoder_model, 
                                             input_seq=encode_series,
                                             pred_steps=pred_steps)
    encode_series = encode_series.reshape(-1,1)
    pred_series = pred_series.reshape(-1,1)   
    target_series = decoder_target_data[sample_ix,:,:1].reshape(-1,1)
    encode_series_tail = np.concatenate([encode_series[-enc_tail_len:],target_series[:1]])
    x_encode = encode_series_tail.shape[0]
    r, p = pearsonr(pred_series.reshape(-1), target_series.reshape(-1))
    mae = np.mean(np.abs(pred_series.reshape(-1) - target_series.reshape(-1)))
    if verbose:
        print(f"Correlation: {r}. P: {p}. MAE: {mae}")
    return r, mae

# %%
encoder_input_data = val_batch[0]
encoder_target_data = val_batch[1]

# %%
n_rows = val_batch[0][0].shape[0] // 2
r_array = np.empty(shape=(n_rows,))
z_array = np.empty(shape=(n_rows,))

sample_maes = np.empty(shape=(n_rows,))
for sample_ix in range(n_rows):
    print(f"Sample: {sample_ix}/{n_rows}", end="\r")
    r, mae = get_corr_mae(encoder_input_data, encoder_target_data, sample_ix=sample_ix, pred_steps=20, verbose=False)
    r_array[sample_ix] = r
    z_array[sample_ix] = 0.5 * np.log((1 + r)/(1-r))
    sample_maes[sample_ix] = mae
z_mean = np.mean(z_array)
batch_r = (np.exp(2 * z_mean) - 1)/(np.exp(2 * z_mean) + 1)
batch_mae = np.mean(sample_maes)
print(f"Batch_r: {batch_r}")
print(f"Absolute Batch_r: {np.mean(np.abs(r_array))}")
print(f"Batch Mae: {batch_mae}")
# Out:
# Batch_r: 0.09730947221597654
# Absolute Batch_r: 0.2861497159718088
# Batch Mae: 0.5907704582024889

# %%
# Plot the distribution of r
import seaborn as sns
sns.distplot(r_array, kde=True, color = 'darkblue',
             kde_kws={'linewidth': 4})

# %%
k = 5
top_k_r = np.abs(r_array).argsort()[-k:]
print(top_k_r)
# Out:
# [795 887 763 600 133]

# %%
for i in top_k_r:
    predict_and_plot(val_batch[0], val_batch[1], sample_ix=i,
                     pred_steps=20)
# Out:
# Correlation: 0.8136161604411648. P: 1.2821037739351545e-05. mae: 0.525826065699556
# Correlation: 0.8198366971028876. P: 9.677636830221185e-06. mae: 0.9177984742304808
# Correlation: 0.8230155052226817. P: 8.347487726122603e-06. mae: 0.3488040859623184
# Correlation: 0.8435307501349303. P: 2.9816296686096444e-06. mae: 0.8188619673350315
# Correlation: 0.9067376294159004. P: 3.598998790418893e-08. mae: 0.8681990511048335

# %%
k = 5
top_k_mae = sample_maes.argsort()[:k]
print(top_k_mae)
# Out:
# [110 188 997 477 212]

# %%
for i in top_k_mae:
    predict_and_plot(val_batch[0], val_batch[1], sample_ix=i,
                     pred_steps=20)
# Out:
# Correlation: -0.1007126978962184. P: 0.6726769939216101. mae: 0.2331520315424754
# Correlation: 0.2889933290988628. P: 0.21654117593588917. mae: 0.23896215152765815
# Correlation: -0.17826186275733444. P: 0.45209116095201307. mae: 0.2784555994084818
# Correlation: -0.09182461827891575. P: 0.700218402502319. mae: 0.2815359978777635
# Correlation: 0.1499315741900294. P: 0.5280910609781099. mae: 0.2891682450693849
