# %% [markdown]
# Encoder Decoder LSTM With logcosh

# %%
# Autoreload
# %load_ext autoreload
# %autoreload

# %%
# Imports
import numpy as np
import json
import pandas as pd
import numpy as np
import time
import string
from matplotlib import pyplot as plt
import tensorflow as tf
import sys
sys.path.append('../../../')
from brain2brain import utils, generators, models
# %matplotlib inline

# TF
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# TCN
from brain2brain.tcn import TCN
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Flatten, GRU, LSTM, RepeatVector, TimeDistributed

from scipy.stats import pearsonr

# %%
train_paths = utils.get_file_paths("/home/tmarcu/brain2brain/brain2brain/train_676_bin_norm_2.txt")
val_paths = utils.get_file_paths("/home/tmarcu/brain2brain/brain2brain/val_676_bin_norm_2.txt")
total_electrode_count = utils.get_file_shape(train_paths[0])[1]
# Electrodes
electrode_count = 1
electrode = 5
lookback = 100
pred_length = 20
# Training Generator
train_generator = generators.FGenerator(file_paths=train_paths,
                                        lookback=lookback,
                                        length=pred_length,
                                        delay=0,
                                        batch_size=1024,
                                        sample_period=1,
                                        electrodes=[electrode],
                                        electrode_output_ix=electrode,
                                        shuffle=True,
                                        teacher_forcing=True,
                                        teacher_forcing_concat=True)
# Validation Generator
val_generator = generators.FGenerator(file_paths=val_paths,
                                        lookback=lookback,
                                        length=pred_length,
                                        delay=0,
                                        batch_size=1024,
                                        sample_period=1,
                                        electrodes=[electrode],
                                        electrode_output_ix=electrode,
                                        shuffle=False,
                                        teacher_forcing=True,
                                        teacher_forcing_concat=True)
# Out:
# (5429, 114)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Dense, Activation, Dropout, Lambda, Multiply, Add, Concatenate
from tensorflow.keras.optimizers import Adam

# convolutional operation parameters
n_filters = 32 # 32 
filter_width = 2
dilation_rates = [2**i for i in range(8)] * 2 

# define an input history series and pass it through a stack of dilated causal convolution blocks. 
history_seq = Input(shape=(None, 1))
x = history_seq

skips = []
for dilation_rate in dilation_rates:
    
    # preprocessing - equivalent to time-distributed dense
    x = Conv1D(16, 1, padding='same', activation='relu')(x) 
    
    # filter convolution
    x_f = Conv1D(filters=n_filters,
                 kernel_size=filter_width, 
                 padding='causal',
                 dilation_rate=dilation_rate)(x)
    
    # gating convolution
    x_g = Conv1D(filters=n_filters,
                 kernel_size=filter_width, 
                 padding='causal',
                 dilation_rate=dilation_rate)(x)
    
    # multiply filter and gating branches
    z = Multiply()([Activation('tanh')(x_f),
                    Activation('sigmoid')(x_g)])
    
    # postprocessing - equivalent to time-distributed dense
    z = Conv1D(16, 1, padding='same', activation='relu')(z)
    
    # residual connection
    x = Add()([x, z])    
    
    # collect skip connections
    skips.append(z)

# add all skip connection outputs 
out = Activation('relu')(Add()(skips))

# final time-distributed dense layers 
out = Conv1D(128, 1, padding='same')(out)
out = Activation('relu')(out)
out = Dropout(.2)(out)
out = Conv1D(1, 1, padding='same')(out)

# extract the last 60 time steps as the training target
def slice(x, seq_length):
    return x[:,-seq_length:,:]

pred_seq_train = Lambda(slice, arguments={'seq_length':20})(out)

model = Model(history_seq, pred_seq_train)
model.compile(Adam(), loss='mean_absolute_error')

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 1)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, None, 16)     32          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, None, 32)     1056        conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, None, 32)     1056        conv1d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None, 32)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, 32)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, None, 32)     0           activation[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, None, 16)     528         multiply[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, None, 16)     0           conv1d[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, None, 16)     272         add[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, None, 32)     1056        conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, None, 32)     1056        conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, 32)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, 32)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, None, 32)     0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, None, 16)     528         multiply_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, 16)     0           conv1d_4[0][0]
#                                                                  conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, None, 16)     272         add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, None, 32)     1056        conv1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, None, 32)     1056        conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, 32)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, 32)     0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, None, 32)     0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, None, 16)     528         multiply_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, 16)     0           conv1d_8[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, None, 16)     272         add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, None, 32)     1056        conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, None, 32)     1056        conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, 32)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, 32)     0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, None, 32)     0           activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, None, 16)     528         multiply_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, 16)     0           conv1d_12[0][0]
#                                                                  conv1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, None, 16)     272         add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, None, 32)     1056        conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, None, 32)     1056        conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, 32)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, 32)     0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, None, 32)     0           activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, None, 16)     528         multiply_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, 16)     0           conv1d_16[0][0]
#                                                                  conv1d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, None, 16)     272         add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, None, 32)     1056        conv1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, None, 32)     1056        conv1d_20[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, 32)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, 32)     0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, None, 32)     0           activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, None, 16)     528         multiply_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, 16)     0           conv1d_20[0][0]
#                                                                  conv1d_23[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, None, 16)     272         add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, None, 32)     1056        conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, None, 32)     1056        conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, 32)     0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, 32)     0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, None, 32)     0           activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, None, 16)     528         multiply_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, 16)     0           conv1d_24[0][0]
#                                                                  conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, None, 16)     272         add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, None, 32)     1056        conv1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, None, 32)     1056        conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, 32)     0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, 32)     0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, None, 32)     0           activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, None, 16)     528         multiply_7[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, 16)     0           conv1d_28[0][0]
#                                                                  conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, None, 16)     272         add_7[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, None, 32)     1056        conv1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, None, 32)     1056        conv1d_32[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, 32)     0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, 32)     0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, None, 32)     0           activation_16[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, None, 16)     528         multiply_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, 16)     0           conv1d_32[0][0]
#                                                                  conv1d_35[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, None, 16)     272         add_8[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, None, 32)     1056        conv1d_36[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, None, 32)     1056        conv1d_36[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, 32)     0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, 32)     0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, None, 32)     0           activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, None, 16)     528         multiply_9[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, 16)     0           conv1d_36[0][0]
#                                                                  conv1d_39[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, None, 16)     272         add_9[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, None, 32)     1056        conv1d_40[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, None, 32)     1056        conv1d_40[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, 32)     0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, 32)     0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, None, 32)     0           activation_20[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, None, 16)     528         multiply_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, 16)     0           conv1d_40[0][0]
#                                                                  conv1d_43[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, None, 16)     272         add_10[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, None, 32)     1056        conv1d_44[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, None, 32)     1056        conv1d_44[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, 32)     0           conv1d_45[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, 32)     0           conv1d_46[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, None, 32)     0           activation_22[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, None, 16)     528         multiply_11[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, 16)     0           conv1d_44[0][0]
#                                                                  conv1d_47[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, None, 16)     272         add_11[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, None, 32)     1056        conv1d_48[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, None, 32)     1056        conv1d_48[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, 32)     0           conv1d_49[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, 32)     0           conv1d_50[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, None, 32)     0           activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, None, 16)     528         multiply_12[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, 16)     0           conv1d_48[0][0]
#                                                                  conv1d_51[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, None, 16)     272         add_12[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, None, 32)     1056        conv1d_52[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, None, 32)     1056        conv1d_52[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, 32)     0           conv1d_53[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, 32)     0           conv1d_54[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, None, 32)     0           activation_26[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, None, 16)     528         multiply_13[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, 16)     0           conv1d_52[0][0]
#                                                                  conv1d_55[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, None, 16)     272         add_13[0][0]
# __________________________________________________________________________________________________
# conv1d_57 (Conv1D)              (None, None, 32)     1056        conv1d_56[0][0]
# __________________________________________________________________________________________________
# conv1d_58 (Conv1D)              (None, None, 32)     1056        conv1d_56[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, 32)     0           conv1d_57[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, 32)     0           conv1d_58[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, None, 32)     0           activation_28[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# conv1d_59 (Conv1D)              (None, None, 16)     528         multiply_14[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, None, 16)     0           conv1d_56[0][0]
#                                                                  conv1d_59[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, None, 16)     272         add_14[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, None, 32)     1056        conv1d_60[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, None, 32)     1056        conv1d_60[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, 32)     0           conv1d_61[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, 32)     0           conv1d_62[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, None, 32)     0           activation_30[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, None, 16)     528         multiply_15[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, None, 16)     0           conv1d_3[0][0]
#                                                                  conv1d_7[0][0]
#                                                                  conv1d_11[0][0]
#                                                                  conv1d_15[0][0]
#                                                                  conv1d_19[0][0]
#                                                                  conv1d_23[0][0]
#                                                                  conv1d_27[0][0]
#                                                                  conv1d_31[0][0]
#                                                                  conv1d_35[0][0]
#                                                                  conv1d_39[0][0]
#                                                                  conv1d_43[0][0]
#                                                                  conv1d_47[0][0]
#                                                                  conv1d_51[0][0]
#                                                                  conv1d_55[0][0]
#                                                                  conv1d_59[0][0]
#                                                                  conv1d_63[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, 16)     0           add_16[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, None, 128)    2176        activation_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, 128)    0           conv1d_64[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, 128)    0           activation_33[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, None, 1)      129         dropout[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, None, 1)      0           conv1d_65[0][0]
# ==================================================================================================
# Total params: 48,657
# Trainable params: 48,657
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
callback_list = [
#         EarlyStopping(
#             monitor="val_loss",
#             patience=2,
#             mode="min"
#         )
]
history = model.fit_generator(generator=train_generator,
                              callbacks=callback_list,
                              epochs=100,
                              validation_data=val_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-6-8f168f2d36bf>:11: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 12 steps, validate for 4 steps
# Epoch 1/100
# 12/12 [==============================] - 17s 1s/step - loss: 0.6861 - val_loss: 0.5718
# Epoch 2/100
# 12/12 [==============================] - 6s 531ms/step - loss: 0.5448 - val_loss: 0.5006
# Epoch 3/100
# 12/12 [==============================] - 6s 517ms/step - loss: 0.5084 - val_loss: 0.4904
# Epoch 4/100
# 12/12 [==============================] - 6s 533ms/step - loss: 0.4998 - val_loss: 0.4874
# Epoch 5/100
# 12/12 [==============================] - 6s 519ms/step - loss: 0.4965 - val_loss: 0.4859
# Epoch 6/100
# 12/12 [==============================] - 6s 517ms/step - loss: 0.4942 - val_loss: 0.4849
# Epoch 7/100
# 12/12 [==============================] - 7s 567ms/step - loss: 0.4932 - val_loss: 0.4847
# Epoch 8/100
# 12/12 [==============================] - 7s 574ms/step - loss: 0.4928 - val_loss: 0.4843
# Epoch 9/100
# 12/12 [==============================] - 7s 572ms/step - loss: 0.4921 - val_loss: 0.4839
# Epoch 10/100
# 12/12 [==============================] - 7s 589ms/step - loss: 0.4917 - val_loss: 0.4839
# Epoch 11/100
# 12/12 [==============================] - 7s 571ms/step - loss: 0.4914 - val_loss: 0.4834
# Epoch 12/100
# 12/12 [==============================] - 7s 569ms/step - loss: 0.4912 - val_loss: 0.4836
# Epoch 13/100
# 12/12 [==============================] - 7s 566ms/step - loss: 0.4909 - val_loss: 0.4831
# Epoch 14/100
# 12/12 [==============================] - 7s 573ms/step - loss: 0.4905 - val_loss: 0.4829
# Epoch 15/100
# 12/12 [==============================] - 7s 576ms/step - loss: 0.4900 - val_loss: 0.4828
# Epoch 16/100
# 12/12 [==============================] - 7s 579ms/step - loss: 0.4898 - val_loss: 0.4829
# Epoch 17/100
# 12/12 [==============================] - 7s 585ms/step - loss: 0.4899 - val_loss: 0.4825
# Epoch 18/100
# 12/12 [==============================] - 7s 577ms/step - loss: 0.4897 - val_loss: 0.4824
# Epoch 19/100
# 12/12 [==============================] - 7s 574ms/step - loss: 0.4893 - val_loss: 0.4822
# Epoch 20/100
# 12/12 [==============================] - 7s 567ms/step - loss: 0.4896 - val_loss: 0.4820
# Epoch 21/100
# 12/12 [==============================] - 7s 575ms/step - loss: 0.4887 - val_loss: 0.4815
# Epoch 22/100
# 12/12 [==============================] - 7s 572ms/step - loss: 0.4885 - val_loss: 0.4818
# Epoch 23/100
# 12/12 [==============================] - 7s 571ms/step - loss: 0.4888 - val_loss: 0.4818
# Epoch 24/100
# 12/12 [==============================] - 7s 590ms/step - loss: 0.4890 - val_loss: 0.4813
# Epoch 25/100
# 12/12 [==============================] - 7s 571ms/step - loss: 0.4885 - val_loss: 0.4822
# Epoch 26/100
# 12/12 [==============================] - 7s 576ms/step - loss: 0.4887 - val_loss: 0.4810
# Epoch 27/100
# 12/12 [==============================] - 7s 576ms/step - loss: 0.4882 - val_loss: 0.4816
# Epoch 28/100
# 12/12 [==============================] - 7s 576ms/step - loss: 0.4885 - val_loss: 0.4820
# Epoch 29/100
# 12/12 [==============================] - 7s 573ms/step - loss: 0.4879 - val_loss: 0.4809
# Epoch 30/100
# 12/12 [==============================] - 7s 575ms/step - loss: 0.4880 - val_loss: 0.4812
# Epoch 31/100
# 12/12 [==============================] - 7s 574ms/step - loss: 0.4880 - val_loss: 0.4808
# Epoch 32/100
# 12/12 [==============================] - 7s 575ms/step - loss: 0.4873 - val_loss: 0.4811
# Epoch 33/100
# 12/12 [==============================] - 7s 575ms/step - loss: 0.4876 - val_loss: 0.4806
# Epoch 34/100
# 12/12 [==============================] - 7s 569ms/step - loss: 0.4876 - val_loss: 0.4805
# Epoch 35/100
# 12/12 [==============================] - 7s 616ms/step - loss: 0.4875 - val_loss: 0.4809
# Epoch 36/100
# 12/12 [==============================] - 7s 569ms/step - loss: 0.4876 - val_loss: 0.4816
# Epoch 37/100
# 12/12 [==============================] - 7s 575ms/step - loss: 0.4875 - val_loss: 0.4808
# Epoch 38/100
# 12/12 [==============================] - 7s 574ms/step - loss: 0.4874 - val_loss: 0.4815
# Epoch 39/100
# 12/12 [==============================] - 7s 576ms/step - loss: 0.4870 - val_loss: 0.4809
# Epoch 40/100
# 12/12 [==============================] - 7s 571ms/step - loss: 0.4870 - val_loss: 0.4804
# Epoch 41/100
# 12/12 [==============================] - 7s 568ms/step - loss: 0.4868 - val_loss: 0.4803
# Epoch 42/100
# 12/12 [==============================] - 7s 573ms/step - loss: 0.4872 - val_loss: 0.4807
# Epoch 43/100
# 12/12 [==============================] - 7s 606ms/step - loss: 0.4873 - val_loss: 0.4812
# Epoch 44/100
# 12/12 [==============================] - 7s 574ms/step - loss: 0.4872 - val_loss: 0.4808
# Epoch 45/100
# 12/12 [==============================] - 7s 577ms/step - loss: 0.4871 - val_loss: 0.4813
# Epoch 46/100
# 12/12 [==============================] - 7s 574ms/step - loss: 0.4866 - val_loss: 0.4805
# Epoch 47/100
# 12/12 [==============================] - 7s 578ms/step - loss: 0.4865 - val_loss: 0.4805
# Epoch 48/100
# 12/12 [==============================] - 7s 572ms/step - loss: 0.4866 - val_loss: 0.4801
# Epoch 49/100
# 12/12 [==============================] - 7s 571ms/step - loss: 0.4864 - val_loss: 0.4806
# Epoch 50/100
# 12/12 [==============================] - 7s 570ms/step - loss: 0.4864 - val_loss: 0.4801
# Epoch 51/100
# 12/12 [==============================] - 7s 570ms/step - loss: 0.4868 - val_loss: 0.4807
# Epoch 52/100
# 12/12 [==============================] - 7s 574ms/step - loss: 0.4865 - val_loss: 0.4802
# Epoch 53/100
# 12/12 [==============================] - 7s 577ms/step - loss: 0.4865 - val_loss: 0.4803
# Epoch 54/100
# 12/12 [==============================] - 7s 572ms/step - loss: 0.4868 - val_loss: 0.4813
# Epoch 55/100
# 12/12 [==============================] - 7s 589ms/step - loss: 0.4873 - val_loss: 0.4801
# Epoch 56/100
# 12/12 [==============================] - 7s 574ms/step - loss: 0.4863 - val_loss: 0.4803
# Epoch 57/100
# 12/12 [==============================] - 7s 573ms/step - loss: 0.4863 - val_loss: 0.4804
# Epoch 58/100
# 12/12 [==============================] - 7s 571ms/step - loss: 0.4863 - val_loss: 0.4803
# Epoch 59/100
# 12/12 [==============================] - 7s 581ms/step - loss: 0.4861 - val_loss: 0.4802
# Epoch 60/100
# 12/12 [==============================] - 7s 574ms/step - loss: 0.4861 - val_loss: 0.4801
# Epoch 61/100
# 12/12 [==============================] - 7s 605ms/step - loss: 0.4860 - val_loss: 0.4800
# Epoch 62/100
# 12/12 [==============================] - 7s 590ms/step - loss: 0.4857 - val_loss: 0.4806
# Epoch 63/100
# 12/12 [==============================] - 7s 576ms/step - loss: 0.4861 - val_loss: 0.4803
# Epoch 64/100
# 12/12 [==============================] - 7s 580ms/step - loss: 0.4861 - val_loss: 0.4801
# Epoch 65/100
# 12/12 [==============================] - 7s 577ms/step - loss: 0.4862 - val_loss: 0.4800
# Epoch 66/100
# 12/12 [==============================] - 7s 569ms/step - loss: 0.4860 - val_loss: 0.4801
# Epoch 67/100
# 12/12 [==============================] - 7s 568ms/step - loss: 0.4855 - val_loss: 0.4804
# Epoch 68/100
# 12/12 [==============================] - 7s 575ms/step - loss: 0.4858 - val_loss: 0.4805
# Epoch 69/100
# 12/12 [==============================] - 7s 577ms/step - loss: 0.4863 - val_loss: 0.4800
# Epoch 70/100
# 12/12 [==============================] - 7s 608ms/step - loss: 0.4861 - val_loss: 0.4818
# Epoch 71/100
# 12/12 [==============================] - 7s 573ms/step - loss: 0.4860 - val_loss: 0.4810
# Epoch 72/100
# 12/12 [==============================] - 7s 575ms/step - loss: 0.4857 - val_loss: 0.4801
# Epoch 73/100
# 12/12 [==============================] - 7s 572ms/step - loss: 0.4860 - val_loss: 0.4805
# Epoch 74/100
# 12/12 [==============================] - 7s 569ms/step - loss: 0.4868 - val_loss: 0.4825
# Epoch 75/100
# 12/12 [==============================] - 7s 573ms/step - loss: 0.4865 - val_loss: 0.4809
# Epoch 76/100
# 12/12 [==============================] - 7s 574ms/step - loss: 0.4858 - val_loss: 0.4815
# Epoch 77/100
# 12/12 [==============================] - 7s 571ms/step - loss: 0.4866 - val_loss: 0.4810
# Epoch 78/100
# 12/12 [==============================] - 7s 569ms/step - loss: 0.4859 - val_loss: 0.4801
# Epoch 79/100
# 12/12 [==============================] - 7s 581ms/step - loss: 0.4857 - val_loss: 0.4807
# Epoch 80/100
# 12/12 [==============================] - 7s 577ms/step - loss: 0.4861 - val_loss: 0.4804
# Epoch 81/100
# 12/12 [==============================] - 7s 590ms/step - loss: 0.4860 - val_loss: 0.4801
# Epoch 82/100
# 12/12 [==============================] - 7s 571ms/step - loss: 0.4853 - val_loss: 0.4800
# Epoch 83/100
# 12/12 [==============================] - 7s 572ms/step - loss: 0.4857 - val_loss: 0.4804
# Epoch 84/100
# 12/12 [==============================] - 7s 570ms/step - loss: 0.4856 - val_loss: 0.4800
# Epoch 85/100
# 12/12 [==============================] - 7s 568ms/step - loss: 0.4852 - val_loss: 0.4807
# Epoch 86/100
# 12/12 [==============================] - 7s 592ms/step - loss: 0.4851 - val_loss: 0.4798
# Epoch 87/100
# 12/12 [==============================] - 7s 569ms/step - loss: 0.4854 - val_loss: 0.4802
# Epoch 88/100
# 12/12 [==============================] - 7s 569ms/step - loss: 0.4851 - val_loss: 0.4805
# Epoch 89/100
# 12/12 [==============================] - 7s 573ms/step - loss: 0.4849 - val_loss: 0.4802
# Epoch 90/100
# 12/12 [==============================] - 7s 576ms/step - loss: 0.4849 - val_loss: 0.4801
# Epoch 91/100
# 12/12 [==============================] - 7s 575ms/step - loss: 0.4846 - val_loss: 0.4801
# Epoch 92/100
# 12/12 [==============================] - 7s 591ms/step - loss: 0.4846 - val_loss: 0.4801
# Epoch 93/100
# 12/12 [==============================] - 7s 615ms/step - loss: 0.4848 - val_loss: 0.4802
# Epoch 94/100
# 12/12 [==============================] - 7s 601ms/step - loss: 0.4846 - val_loss: 0.4802
# Epoch 95/100
# 12/12 [==============================] - 7s 591ms/step - loss: 0.4848 - val_loss: 0.4799
# Epoch 96/100
# 12/12 [==============================] - 7s 575ms/step - loss: 0.4846 - val_loss: 0.4803
# Epoch 97/100
# 12/12 [==============================] - 7s 578ms/step - loss: 0.4845 - val_loss: 0.4802
# Epoch 98/100
# 12/12 [==============================] - 7s 574ms/step - loss: 0.4845 - val_loss: 0.4802
# Epoch 99/100
# 12/12 [==============================] - 7s 573ms/step - loss: 0.4842 - val_loss: 0.4800
# Epoch 100/100
# 12/12 [==============================] - 7s 570ms/step - loss: 0.4844 - val_loss: 0.4802

# %%
from tensorflow.keras.models import model_from_json

file_name = "models/wavenet_o2o"
# serialize model to JSON
model_json = model.to_json()
with open(f"{file_name}.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights(f"{file_name}.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-74ac7c54ad16> in <module>
#       3 file_name = "models/wavenet_o2o"
#       4 # serialize model to JSON
# ----> 5 model_json = model.to_json()
#       6 with open(f"{file_name}.json", "w") as json_file:
#       7     json_file.write(model_json)
#
# NameError: name 'model' is not defined

# %%
from tensorflow.keras.models import model_from_json

file_name = "models/wavenet_o2o"
# load json and create model
json_file = open(f'{file_name}.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights(f"{file_name}.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error Loss')
plt.title('Loss Over Time')
plt.legend(['Train','Valid'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b6fe65cffa51> in <module>
# ----> 1 plt.plot(history.history['loss'])
#       2 plt.plot(history.history['val_loss'])
#       3
#       4 plt.xlabel('Epoch')
#       5 plt.ylabel('Mean Absolute Error Loss')
#
# NameError: name 'history' is not defined

# %%
def predict_sequence_o2o(input_sequence, pred_steps, model):
    lookback = input_sequence.shape[1]
#     print(input_sequence.shape)
    history_sequence = input_sequence.reshape((1, lookback, 1))
    pred_sequence = np.zeros((pred_steps,)) # initialize output (pred_steps time steps)  
    
    for i in range(pred_steps):
        # record next time step prediction (last time step of model output) 
        last_step_pred = model.predict(history_sequence)
        last_step_pred = last_step_pred.reshape(-1)

        pred_sequence[i] = last_step_pred[-1]
        
        # add the next time step prediction to the history sequence
        history_sequence = np.concatenate([history_sequence[:, -(lookback-1):, :], 
                                           last_step_pred[-1].reshape(1, 1, 1)], axis=1)

    return pred_sequence

# %%
def predict_and_plot(encoder_input_data, decoder_target_data, sample_ix, pred_steps: int, enc_tail_len=100):
    encode_series = encoder_input_data[sample_ix:sample_ix+1,:,:] 
    pred_series = predict_sequence_o2o(encode_series,
                                              pred_steps, model)
    encode_series = encode_series.reshape(-1,1)
    pred_series = pred_series.reshape(-1,1)   
    target_series = decoder_target_data[sample_ix,:,:1].reshape(-1,1)
    encode_series_tail = np.concatenate([encode_series[-enc_tail_len:],target_series[:1]])
    x_encode = encode_series_tail.shape[0]
    r, p = pearsonr(pred_series.reshape(-1), target_series.reshape(-1))
    mae = np.mean(np.abs(pred_series.reshape(-1) - target_series.reshape(-1)))
    print(f"Correlation: {r}. P: {p}. Mae: {mae}")
    plt.figure(figsize=(10,6))   
    
    plt.plot(range(1,x_encode+1),encode_series_tail)
    plt.plot(range(x_encode,x_encode+pred_steps),target_series,color='orange')
    plt.plot(range(x_encode,x_encode+pred_steps),pred_series,color='teal',linestyle='--')
    
    plt.title('Encoder Series Tail of Length %d, Target Series, and Predictions' % enc_tail_len)
    plt.legend(['Encoding Series','Target Series','Predictions'])

# %%
val_batch = val_generator[0]

# %%
len(val_batch[0][0])
# Out:
# 119

# %%
predict_and_plot(val_batch[0], val_batch[1], sample_ix=0, pred_steps=20)
# Out:
# Correlation: 0.0138040384685321. P: 0.9539390331786345. Mae: 0.5070329672647802

# %%
def get_corr_mae(encoder_input_data, decoder_target_data, sample_ix, pred_steps: int,
                 enc_tail_len=100, verbose=True):
    encode_series = encoder_input_data[sample_ix:sample_ix+1,:,:] 
    pred_series = predict_sequence_o2o(encode_series,
                                              pred_steps, model)
    encode_series = encode_series.reshape(-1,1)
    pred_series = pred_series.reshape(-1,1)   
    target_series = decoder_target_data[sample_ix,:,:1].reshape(-1,1)
    encode_series_tail = np.concatenate([encode_series[-enc_tail_len:],target_series[:1]])
    x_encode = encode_series_tail.shape[0]
    r, p = pearsonr(pred_series.reshape(-1), target_series.reshape(-1))
    mae = np.mean(np.abs(pred_series.reshape(-1) - target_series.reshape(-1)))
    if verbose:
        print(f"Correlation: {r}. P: {p}. MAE: {mae}")
    return r, mae

# %%
encoder_input_data = val_batch[0]
encoder_target_data = val_batch[1]

# %%
n_rows = int(encoder_input_data.shape[0]//2)
r_array = np.empty(shape=(n_rows,))
z_array = np.empty(shape=(n_rows,))
sample_maes = np.empty(shape=(n_rows,))
for sample_ix in range(n_rows):
    print(f"Sample: {sample_ix}/{n_rows}", end="\r")
    r, mae = get_corr_mae(encoder_input_data, encoder_target_data, sample_ix=sample_ix, pred_steps=20, verbose=False)
    r_array[sample_ix] = r
    z_array[sample_ix] = 0.5 * np.log((1 + r)/(1-r))
    sample_maes[sample_ix] = mae
z_mean = np.mean(z_array)
batch_r = (np.exp(2 * z_mean) - 1)/(np.exp(2 * z_mean) + 1)
batch_mae = np.mean(sample_maes)
print(f"Batch_r: {batch_r}")
print(f"Absolute Batch_r: {np.mean(np.abs(r_array))}")
print(f"Batch Mae: {batch_mae}")
# Out:
# Batch_r: -0.15857563394673854
# Absolute Batch_r: 0.2916498338131818
# Batch Mae: 0.5478843748913538

# %%
# Plot the distribution of r
import seaborn as sns
sns.distplot(r_array, kde=True, color = 'darkblue',
             kde_kws={'linewidth': 4})

# %%
k = 5
top_k_r = np.abs(r_array).argsort()[-k:]
print(top_k_r)
# Out:
# [217 399 456 166 133]

# %%
for i in top_k_r:
    predict_and_plot(val_batch[0], val_batch[1], sample_ix=i,
                     pred_steps=20)
# Out:
# Correlation: 0.6024749127678023. P: 0.00493463537541163. Mae: 0.4935703237582221
# Correlation: -0.6383682492846953. P: 0.0024533299697378393. Mae: 0.5661543493230486
# Correlation: -0.6440409647275406. P: 0.002179453931717607. Mae: 0.7900055237265328
# Correlation: -0.6532952544534215. P: 0.0017876313147215438. Mae: 0.9332068910872173
# Correlation: -0.7367889527873044. P: 0.0002111459604447229. Mae: 0.8425585493107153

# %%
k = 5
top_k_mae = sample_maes.argsort()[:k]
print(top_k_mae)
# Out:
# [ 8 28 58 50 26]

# %%
for i in top_k_mae:
    predict_and_plot(val_batch[0], val_batch[1], sample_ix=i,
                     pred_steps=20)
# Out:
# Correlation: 0.14922505604717562. P: 0.5300591913589096. Mae: 0.32453120077997555
# Correlation: -0.02387774418186725. P: 0.9204059096240412. Mae: 0.3433998176016252
# Correlation: 0.1686649297173355. P: 0.47718213717675195. Mae: 0.3671228321755339
# Correlation: -0.3643710821502024. P: 0.11423174848338913. Mae: 0.3688957804156949
# Correlation: 0.286204972983597. P: 0.22120709606789754. Mae: 0.37666584030945377

# %%
def predict_sequence_o2o_window(input_sequence, pred_steps, model, lookback=lookback):
    history_sequence = input_sequence.reshape((1, lookback, 1))
    pred_sequence = np.zeros((pred_steps,)) # initialize output (pred_steps time steps)  
    
    for i in range(pred_steps):
        # record next time step prediction (last time step of model output) 
        last_step_pred = model.predict(history_sequence)
        last_step_pred = last_step_pred.reshape(-1)

        pred_sequence[i] = last_step_pred[-1]
        
        # add the next time step prediction to the history sequence
        history_sequence = np.concatenate([history_sequence[:, -(lookback-1):, :], 
                                           last_step_pred[-1].reshape(1, 1, 1)], axis=1)

    return pred_sequence

def moving_window_pred_o2o(input_sequence,
                           lookback,
                           pred_steps,
                           electrode_count,
                           model):
    # for each window of lookback predict steps and then
    # move window up by pred steps and repeat
    # window = input_sequence[w_start: w_end]
    final_array = np.empty(shape=(input_sequence.shape[0], electrode_count))
    print(final_array.shape)
    w_start = 0
    w_end = w_start + lookback
    final_array[w_start : w_end] = input_sequence[w_start : w_end]
    while w_end + pred_steps < input_sequence.shape[0]:
        window_lookback = input_sequence[w_start: w_end]
        pred_seq = predict_sequence_o2o_window(window_lookback, pred_steps, model, lookback=lookback)
        final_array[w_end:w_end+pred_steps] = pred_seq.reshape(pred_steps, electrode_count)
        w_start += pred_steps
        w_end += pred_steps
    return final_array

def get_corr_mae_conv(input_seq,
                      lookback,
                      pred_length,
                      electrode_count,
                      electrode,
                      model,
                      enc_tail_len=100,
                      verbose=True):
    
    
    input_seq = input_seq[:,electrode].reshape(input_seq.shape[0], electrode_count)

    predicted_series = moving_window_pred_o2o(input_seq,
                                              lookback = lookback,
                                              pred_steps = pred_length,
                                              electrode_count=electrode_count,
                                              model=model)
    
    input_seq = input_seq[lookback:,:]

    predicted_series = predicted_series[lookback:,:]

    input_series = input_seq.reshape(-1,1)
    pred_series = predicted_series.reshape(-1,1)   
    
    x_encode = input_series.shape[0]
    
    r, p = pearsonr(pred_series.reshape(-1), input_series.reshape(-1))
    mae = np.mean(np.abs(pred_series.reshape(-1) - input_series.reshape(-1)))
    if verbose:
        print(f"Correlation: {r}. P: {p}. MAE: {mae}")
    plt.figure(figsize=(10,6))   
    plt.plot(range(x_encode),input_series)
    plt.plot(range(x_encode),pred_series,color='orange',linestyle='--')
    plt.legend(['Input Series', 'Predictions'])
    return r, mae

def get_corr_mae_conv_step(input_seq,
                           lookback,
                           k,
                           pred_length,
                           electrode_count,
                           electrode,
                           model,
                           enc_tail_len=100,
                           verbose=True):
    
    
    input_seq = input_seq[:,electrode].reshape((input_seq.shape[0], electrode_count))

    predicted_series = moving_window_pred_o2o_step(input_seq,
                                                   lookback = lookback,
                                                   k=k,
                                                   pred_steps = pred_length,
                                                   electrode_count=electrode_count,
                                                   model=model)
    
    input_seq = input_seq[lookback:,:]

    predicted_series = predicted_series[lookback:,:]

    input_series = input_seq.reshape(-1,1)
    pred_series = predicted_series.reshape(-1,1)   
    
    x_encode = input_series.shape[0]
    
    r, p = pearsonr(pred_series.reshape(-1), input_series.reshape(-1))
    mae = np.mean(np.abs(pred_series.reshape(-1) - input_series.reshape(-1)))
    if verbose:
        print(f"Correlation: {r}. P: {p}. MAE: {mae}")
    plt.figure(figsize=(10,6))   
    plt.plot(range(x_encode),input_series)
    plt.plot(range(x_encode),pred_series,color='orange',linestyle='--')
    plt.legend(['Input Series', 'Predictions'])
    return r, mae

def moving_window_pred_o2o_step(input_sequence,
                                lookback,
                                pred_steps,
                                k,
                                electrode_count,
                                model):
    # for each window of lookback predict steps and then
    # move window up by pred steps and repeat
    # window = input_sequence[w_start: w_end]
    final_array = np.empty(shape=(input_sequence.shape[0], electrode_count))
    w_start = 0
    w_end = w_start + lookback
    final_array[w_start : w_end + k, :] = input_sequence[w_start : w_end + k, :]
    print(final_array.shape)
    full_length = int(len(input_sequence))
    print(full_length)
    i = w_end + k
    while i < full_length:
        window_lookback = np.array([input_sequence[w_start: w_end]])
#         print(window_lookback.shape)
        pred_steps = model.predict(window_lookback)
#         print(pred_steps.reshape((20, 1)))
#         print(pred_steps.shape)
        final_array[w_end + k] = pred_steps[:,k,:].reshape((1, 1))
        w_end += 1
        w_start += 1
        i += 1
    return final_array

# %%
data = np.load(val_paths[0])

# %%
get_corr_mae_conv(data[:2048,:], lookback, pred_length, electrode_count=1, electrode=electrode, model=model)
# Out:
# (2048, 1)
# Correlation: 0.5118263894328313. P: 1.5336528028370945e-130. MAE: 0.6034965123383602
# (0.5118263894328313, 0.6034965123383602)

# %%
get_corr_mae_conv_step(data[:200,:], lookback, 0, pred_length, electrode_count=1, electrode=electrode, model=model)
# Out:
# (200, 1)
# 200
# Correlation: 0.27823864470794357. P: 0.005063285451584091. MAE: 0.6777178871741775
# (0.27823864470794357, 0.6777178871741775)

# %%
get_corr_mae_conv_step(data[:2048,:], lookback, 0, pred_length, electrode_count=1, electrode=electrode, model=model)
# Out:
# (2048, 1)
# 2048
# Correlation: 0.364908922712948. P: 2.0370491162056706e-62. MAE: 0.6815471115260601
# (0.364908922712948, 0.6815471115260601)

# %%
get_corr_mae_conv_step(data[:2048,:], lookback, 5, pred_length, electrode_count=1, electrode=electrode, model=model)
# Out:
# (2048, 1)
# 2048
# Correlation: 0.36613497266054856. P: 7.419976595307928e-63. MAE: 0.6808083250915143
# (0.36613497266054856, 0.6808083250915143)

# %%
get_corr_mae_conv_step(data[:2048,:], lookback, 10, pred_length, electrode_count=1, electrode=electrode, model=model)
# Out:
# (2048, 1)
# 2048
# Correlation: 0.3663345083177163. P: 6.292754421754327e-63. MAE: 0.6798556083012023
# (0.3663345083177163, 0.6798556083012023)

# %% [markdown]
# # TEST DATA

# %%
test_paths = utils.get_file_paths("/home/tmarcu/brain2brain/brain2brain/test_676_bin_norm_2.txt")

# %%
test_paths[0]
# Out:
# '/projects/HASSON/247/data/binned_conversations/676_bin_norm_2/bin_norm_2_NY676_618_Part5-one_conversation1/bin_norm_2_NY676_618_Part5-one_conversation1.npy'

# %%
for path in test_paths:
    utils.get_file_shape(path)
# Out:
# (163846, 114)
# (102096, 114)
# (73475, 114)
# (33158, 114)
# (17795, 114)
# (64950, 114)
# (92170, 114)
# (83951, 114)
# (42936, 114)
# (21311, 114)

# %%
test_data = np.load(test_paths[0])

# %%
get_corr_mae_conv(test_data[:2100,:], lookback, pred_length, electrode_count=1, electrode=electrode, model=model)
# Out:
# (2100, 1)
# Correlation: 0.3081499974253178. P: 2.975790190162424e-45. MAE: 0.7039451905114824
# (0.3081499974253178, 0.7039451905114824)

# %%
get_corr_mae_conv(test_data[250:500,:], lookback, pred_length, electrode_count=1, electrode=electrode, model=model)
# Out:
# (250, 1)
# Correlation: 0.32349105458211347. P: 5.392846303911247e-05. MAE: 0.6280222457483249
# (0.32349105458211347, 0.6280222457483249)

# %%
get_corr_mae_conv(test_data[0:1100,:], lookback, pred_length, electrode_count=1, electrode=electrode, model=model)
# Out:
# (1100, 1)
# Correlation: 0.17556833336237568. P: 2.290701016959834e-08. MAE: 0.7446331148810469
# (0.17556833336237568, 0.7446331148810469)

# %%
get_corr_mae_conv_step(test_data[:250,:], lookback, 0, pred_length, electrode_count=1, electrode=electrode, model=model)
# Out:
# (250, 1)
# 250
# Correlation: -0.16183259923678867. P: 0.047870332844490646. MAE: 0.7686269038186343
# (-0.16183259923678867, 0.7686269038186343)

# %%
get_corr_mae_conv_step(test_data[:2100,:], lookback, 0, pred_length, electrode_count=1, electrode=electrode, model=model)
# Out:
# (2100, 1)
# 2100
# Correlation: 0.133172051145615. P: 2.251207603395366e-09. MAE: 0.8108670134178017
# (0.133172051145615, 0.8108670134178017)

# %%
get_corr_mae_conv_step(test_data[:2100,:], lookback, 5, pred_length, electrode_count=1, electrode=electrode, model=model)
# Out:
# (2100, 1)
# 2100
# Correlation: 0.13658825854319145. P: 8.604282923969973e-10. MAE: 0.8084768924696277
# (0.13658825854319145, 0.8084768924696277)

# %%
get_corr_mae_conv_step(test_data[:2100,:], lookback, 10, pred_length, electrode_count=1, electrode=electrode, model=model)
# Out:
# (2100, 1)
# 2100
# Correlation: 0.14264175146489683. P: 1.4750189820360206e-10. MAE: 0.8052751527126227
# (0.14264175146489683, 0.8052751527126227)

# %%
get_corr_mae_conv_step(test_data[:1100,:], lookback, 10, pred_length, electrode_count=1, electrode=electrode, model=model)
# Out:
# (1100, 1)
# 1100
# Correlation: 0.15290037144195429. P: 1.1877115441449238e-06. MAE: 0.7970921652602144
# (0.15290037144195429, 0.7970921652602144)

# %%
# Test_gene
test_generator = generators.FGenerator(file_paths=test_paths,
                                        lookback=lookback,
                                        length=pred_length,
                                        delay=0,
                                        batch_size=2048,
                                        sample_period=1,
                                        electrodes=[electrode],
                                        electrode_output_ix=electrode,
                                        shuffle=False,
                                        teacher_forcing=True,
                                        teacher_forcing_concat=True)

# %%
len(test_generator)
# Out:
# 2

# %%
test_batch = test_generator[0]

# %%
encoder_input_data = val_batch[0]
encoder_target_data = val_batch[1]

# %%
n_rows = int(encoder_input_data.shape[0]//2)
r_array = np.empty(shape=(n_rows,))
z_array = np.empty(shape=(n_rows,))
sample_maes = np.empty(shape=(n_rows,))
for sample_ix in range(n_rows):
    print(f"Sample: {sample_ix}/{n_rows}", end="\r")
    r, mae = get_corr_mae(encoder_input_data, encoder_target_data, sample_ix=sample_ix, pred_steps=20, verbose=False)
    r_array[sample_ix] = r
    z_array[sample_ix] = 0.5 * np.log((1 + r)/(1-r))
    sample_maes[sample_ix] = mae
z_mean = np.mean(z_array)
batch_r = (np.exp(2 * z_mean) - 1)/(np.exp(2 * z_mean) + 1)
batch_mae = np.mean(sample_maes)
print(f"Batch_r: {batch_r}")
print(f"Absolute Batch_r: {np.mean(np.abs(r_array))}")
print(f"Batch Mae: {batch_mae}")
# Out:
# Sample: 56/512
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-f45718d4fa6e> in <module>
#       5 for sample_ix in range(n_rows):
#       6     print(f"Sample: {sample_ix}/{n_rows}", end="\r")
# ----> 7     r, mae = get_corr_mae(encoder_input_data, encoder_target_data, sample_ix=sample_ix, pred_steps=20, verbose=False)
#       8     r_array[sample_ix] = r
#       9     z_array[sample_ix] = 0.5 * np.log((1 + r)/(1-r))
#
# <ipython-input-62-dc0041b2ebc7> in get_corr_mae(encoder_input_data, decoder_target_data, sample_ix, pred_steps, enc_tail_len, verbose)
#       3     encode_series = encoder_input_data[sample_ix:sample_ix+1,:,:]
#       4     pred_series = predict_sequence_o2o(encode_series,
# ----> 5                                               pred_steps, model)
#       6     encode_series = encode_series.reshape(-1,1)
#       7     pred_series = pred_series.reshape(-1,1)
#
# <ipython-input-57-ec583ff18041> in predict_sequence_o2o(input_sequence, pred_steps, model)
#       7     for i in range(pred_steps):
#       8         # record next time step prediction (last time step of model output)
# ----> 9         last_step_pred = model.predict(history_sequence)
#      10         last_step_pred = last_step_pred.reshape(-1)
#      11
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1011         max_queue_size=max_queue_size,
#    1012         workers=workers,
# -> 1013         use_multiprocessing=use_multiprocessing)
#    1014
#    1015   def reset_metrics(self):
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in predict(self, model, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing, **kwargs)
#     496         model, ModeKeys.PREDICT, x=x, batch_size=batch_size, verbose=verbose,
#     497         steps=steps, callbacks=callbacks, max_queue_size=max_queue_size,
# --> 498         workers=workers, use_multiprocessing=use_multiprocessing, **kwargs)
#     499
#     500
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in _model_iteration(self, model, mode, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, **kwargs)
#     424           max_queue_size=max_queue_size,
#     425           workers=workers,
# --> 426           use_multiprocessing=use_multiprocessing)
#     427       total_samples = _get_total_number_of_samples(adapter)
#     428       use_sample = total_samples is not None
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in _process_inputs(model, mode, x, y, batch_size, epochs, sample_weights, class_weights, shuffle, steps, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     704       max_queue_size=max_queue_size,
#     705       workers=workers,
# --> 706       use_multiprocessing=use_multiprocessing)
#     707
#     708   return adapter
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     353       return flat_dataset
#     354
# --> 355     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     356
#     357     dataset = self.slice_inputs(indices_dataset, inputs)
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in flat_map(self, map_func)
#    1613       Dataset: A `Dataset`.
#    1614     """
# -> 1615     return FlatMapDataset(self, map_func)
#    1616
#    1617   def interleave(self,
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func)
#    3956     self._input_dataset = input_dataset
#    3957     self._map_func = StructuredFunctionWrapper(
# -> 3958         map_func, self._transformation_name(), dataset=input_dataset)
#    3959     if not isinstance(self._map_func.output_structure, DatasetSpec):
#    3960       raise TypeError(
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    3145       with tracking.resource_tracker_scope(resource_tracker):
#    3146         # TODO(b/141462134): Switch to using garbage collection.
# -> 3147         self._function = wrapper_fn._get_concrete_function_internal()
#    3148
#    3149         if add_to_graph:
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _get_concrete_function_internal(self, *args, **kwargs)
#    2393     """Bypasses error checking when getting a graph function."""
#    2394     graph_function = self._get_concrete_function_internal_garbage_collected(
# -> 2395         *args, **kwargs)
#    2396     # We're returning this concrete function to someone, and they may keep a
#    2397     # reference to the FuncGraph without keeping a reference to the
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2387       args, kwargs = None, None
#    2388     with self._lock:
# -> 2389       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2390     return graph_function
#    2391
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    2701
#    2702       self._function_cache.missed.add(call_context_key)
# -> 2703       graph_function = self._create_graph_function(args, kwargs)
#    2704       self._function_cache.primary[cache_key] = graph_function
#    2705       return graph_function, args, kwargs
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    2591             arg_names=arg_names,
#    2592             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 2593             capture_by_value=self._capture_by_value),
#    2594         self._function_attributes,
#    2595         # Tell the ConcreteFunction to clean up its graph once it goes out of
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     976                                           converted_func)
#     977
# --> 978       func_outputs = python_func(*func_args, **func_kwargs)
#     979
#     980       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in wrapper_fn(*args)
#    3138           attributes=defun_kwargs)
#    3139       def wrapper_fn(*args):  # pylint: disable=missing-docstring
# -> 3140         ret = _wrapper_helper(*args)
#    3141         ret = structure.to_tensor_list(self._output_structure, ret)
#    3142         return [ops.convert_to_tensor(t) for t in ret]
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in _wrapper_helper(*args)
#    3080         nested_args = (nested_args,)
#    3081
# -> 3082       ret = autograph.tf_convert(func, ag_ctx)(*nested_args)
#    3083       # If `func` returns a list of tensors, `nest.flatten()` and
#    3084       # `ops.convert_to_tensor()` would conspire to attempt to stack
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     232           optional_features=optional_features)
#     233       try:
# --> 234         return converted_call(f, args, kwargs, options=options)
#     235       except Exception as e:  # pylint:disable=broad-except
#     236         if hasattr(e, 'ag_error_metadata'):
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     457
#     458   if not options.user_requested and conversion.is_whitelisted_for_graph(f):
# --> 459     return _call_unconverted(f, args, kwargs, options)
#     460
#     461   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     328   try:
#     329     if kwargs is not None:
# --> 330       return f(*args, **kwargs)
#     331     else:
#     332       return f(*args)
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/data_adapter.py in slice_batch_indices(indices)
#     345       if self._partial_batch_size:
#     346         index_remainder = dataset_ops.DatasetV2.from_tensors(array_ops.slice(
# --> 347             indices, [num_in_full_batch], [self._partial_batch_size]))
#     348         flat_dataset = flat_dataset.concatenate(index_remainder)
#     349
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in from_tensors(tensors)
#     564       Dataset: A `Dataset`.
#     565     """
# --> 566     return TensorDataset(tensors)
#     567
#     568   @staticmethod
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in __init__(self, element)
#    2763   def __init__(self, element):
#    2764     """See `Dataset.from_tensors()` for details."""
# -> 2765     element = structure.normalize_element(element)
#    2766     self._structure = structure.type_spec_from_value(element)
#    2767     self._tensors = structure.to_tensor_list(self._structure, element)
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/data/util/structure.py in normalize_element(element)
#      91     for i, t in enumerate(components):
#      92       try:
# ---> 93         spec = type_spec_from_value(t, use_fallback=False)
#      94       except TypeError:
#      95         # TypeError indicates it was not possible to compute a `TypeSpec` for
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/data/util/structure.py in type_spec_from_value(element, use_fallback)
#     419       is not supported.
#     420   """
# --> 421   spec = type_spec._type_spec_from_value(element)  # pylint: disable=protected-access
#     422   if spec is not None:
#     423     return spec
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/framework/type_spec.py in _type_spec_from_value(value)
#     499   if isinstance(value, ops.Tensor):
#     500     # Note: we do not include Tensor names when constructing TypeSpecs.
# --> 501     return tensor_spec.TensorSpec(value.shape, value.dtype)
#     502
#     503   if isinstance(value, composite_tensor.CompositeTensor):
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_spec.py in __init__(self, shape, dtype, name)
#      49         not convertible to a `tf.DType`.
#      50     """
# ---> 51     self._shape = tensor_shape.TensorShape(shape)
#      52     try:
#      53       self._shape_tuple = tuple(self.shape.as_list())
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_shape.py in __init__(self, dims)
#     761         ]
#     762     elif isinstance(dims, TensorShape):
# --> 763       self._dims = dims.dims
#     764     else:
#     765       try:
#
# ~/.conda/envs/brain2brain_env/lib/python3.7/site-packages/tensorflow_core/python/framework/tensor_shape.py in dims(self)
#     807     return None
#     808
# --> 809   @property
#     810   def dims(self):
#     811     """Returns a list of Dimensions, or None if the shape is unspecified."""
#
# KeyboardInterrupt:
