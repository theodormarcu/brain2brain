# %% [markdown]
# # Wavenet

# %% [markdown]
# Encoder Decoder LSTM With logcosh

# %%
# Autoreload
# %load_ext autoreload
# %autoreload 2

# %%
# Imports
import numpy as np
import json
import pandas as pd
import numpy as np
import time
import string
from matplotlib import pyplot as plt
import tensorflow as tf
import sys
sys.path.append('../../../')
from brain2brain import utils, generators, models
# %matplotlib inline

# TF
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# TCN
from brain2brain.tcn import TCN
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Flatten, GRU, LSTM, RepeatVector, TimeDistributed
from tensorflow.keras.models import model_from_json


from scipy.stats import pearsonr

# %%
train_paths = utils.get_file_paths("/home/tmarcu/brain2brain/brain2brain/train_676_bin_norm_2.txt")
val_paths = utils.get_file_paths("/home/tmarcu/brain2brain/brain2brain/val_676_bin_norm_2.txt")
total_electrode_count = utils.get_file_shape(train_paths[0])[1]
# Electrodes
electrode_count = 114
electrodes = range(114)
electrode = 5
lookback = 100
pred_length = 20
# Training Generator
train_generator = generators.FGenerator(file_paths=train_paths,
                                        lookback=lookback,
                                        length=pred_length,
                                        delay=0,
                                        batch_size=1024,
                                        sample_period=1,
                                        electrodes=electrodes,
                                        electrode_output_ix=electrode,
                                        shuffle=True,
                                        teacher_forcing=True,
                                        teacher_forcing_concat=True)
# Validation Generator
val_generator = generators.FGenerator(file_paths=val_paths,
                                        lookback=lookback,
                                        length=pred_length,
                                        delay=0,
                                        batch_size=1024,
                                        sample_period=1,
                                        electrodes=electrodes,
                                        electrode_output_ix=electrode,
                                        shuffle=False,
                                        teacher_forcing=True,
                                        teacher_forcing_concat=True)
# Out:
# (5429, 114)

# %%
train_generator[0][0].shape
train_generator[0][1].shape
# Out:
# (1024, 20, 1)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Dense, Activation, Dropout, Lambda, Multiply, Add, Concatenate
from tensorflow.keras.optimizers import Adam

# convolutional operation parameters
n_filters = 32 # 32 
filter_width = 2
dilation_rates = [2**i for i in range(8)] * 2 

# define an input history series and pass it through a stack of dilated causal convolution blocks. 
history_seq = Input(shape=(None, electrode_count))
x = history_seq

skips = []
for dilation_rate in dilation_rates:
    
    # preprocessing - equivalent to time-distributed dense
    x = Conv1D(16, 1, padding='same', activation='relu')(x) 
    
    # filter convolution
    x_f = Conv1D(filters=n_filters,
                 kernel_size=filter_width, 
                 padding='causal',
                 dilation_rate=dilation_rate)(x)
    
    # gating convolution
    x_g = Conv1D(filters=n_filters,
                 kernel_size=filter_width, 
                 padding='causal',
                 dilation_rate=dilation_rate)(x)
    
    # multiply filter and gating branches
    z = Multiply()([Activation('tanh')(x_f),
                    Activation('sigmoid')(x_g)])
    
    # postprocessing - equivalent to time-distributed dense
    z = Conv1D(16, 1, padding='same', activation='relu')(z)
    
    # residual connection
    x = Add()([x, z])    
    
    # collect skip connections
    skips.append(z)

# add all skip connection outputs 
out = Activation('relu')(Add()(skips))

# final time-distributed dense layers 
out = Conv1D(128, 1, padding='same')(out)
out = Activation('relu')(out)
out = Dropout(.2)(out)
out = Conv1D(1, 1, padding='same')(out)

# extract the last 60 time steps as the training target
def slice(x, seq_length):
    return x[:,-seq_length:,:]

pred_seq_train = Lambda(slice, arguments={'seq_length':20})(out)

model = Model(history_seq, pred_seq_train)
model.compile(Adam(), loss='mean_absolute_error')

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 114)]  0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, None, 16)     1840        input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, None, 32)     1056        conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, None, 32)     1056        conv1d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None, 32)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, 32)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, None, 32)     0           activation[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, None, 16)     528         multiply[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, None, 16)     0           conv1d[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, None, 16)     272         add[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, None, 32)     1056        conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, None, 32)     1056        conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, 32)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, 32)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, None, 32)     0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, None, 16)     528         multiply_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, 16)     0           conv1d_4[0][0]
#                                                                  conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, None, 16)     272         add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, None, 32)     1056        conv1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, None, 32)     1056        conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, 32)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, 32)     0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, None, 32)     0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, None, 16)     528         multiply_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, 16)     0           conv1d_8[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, None, 16)     272         add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, None, 32)     1056        conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, None, 32)     1056        conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, 32)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, 32)     0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, None, 32)     0           activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, None, 16)     528         multiply_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, 16)     0           conv1d_12[0][0]
#                                                                  conv1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, None, 16)     272         add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, None, 32)     1056        conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, None, 32)     1056        conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, 32)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, 32)     0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, None, 32)     0           activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, None, 16)     528         multiply_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, 16)     0           conv1d_16[0][0]
#                                                                  conv1d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, None, 16)     272         add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, None, 32)     1056        conv1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, None, 32)     1056        conv1d_20[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, 32)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, 32)     0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, None, 32)     0           activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, None, 16)     528         multiply_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, 16)     0           conv1d_20[0][0]
#                                                                  conv1d_23[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, None, 16)     272         add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, None, 32)     1056        conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, None, 32)     1056        conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, 32)     0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, 32)     0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, None, 32)     0           activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, None, 16)     528         multiply_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, 16)     0           conv1d_24[0][0]
#                                                                  conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, None, 16)     272         add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, None, 32)     1056        conv1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, None, 32)     1056        conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, 32)     0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, 32)     0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, None, 32)     0           activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, None, 16)     528         multiply_7[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, 16)     0           conv1d_28[0][0]
#                                                                  conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, None, 16)     272         add_7[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, None, 32)     1056        conv1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, None, 32)     1056        conv1d_32[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, 32)     0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, 32)     0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, None, 32)     0           activation_16[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, None, 16)     528         multiply_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, 16)     0           conv1d_32[0][0]
#                                                                  conv1d_35[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, None, 16)     272         add_8[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, None, 32)     1056        conv1d_36[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, None, 32)     1056        conv1d_36[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, 32)     0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, 32)     0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, None, 32)     0           activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, None, 16)     528         multiply_9[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, 16)     0           conv1d_36[0][0]
#                                                                  conv1d_39[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, None, 16)     272         add_9[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, None, 32)     1056        conv1d_40[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, None, 32)     1056        conv1d_40[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, 32)     0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, 32)     0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, None, 32)     0           activation_20[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, None, 16)     528         multiply_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, 16)     0           conv1d_40[0][0]
#                                                                  conv1d_43[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, None, 16)     272         add_10[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, None, 32)     1056        conv1d_44[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, None, 32)     1056        conv1d_44[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, 32)     0           conv1d_45[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, 32)     0           conv1d_46[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, None, 32)     0           activation_22[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, None, 16)     528         multiply_11[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, 16)     0           conv1d_44[0][0]
#                                                                  conv1d_47[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, None, 16)     272         add_11[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, None, 32)     1056        conv1d_48[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, None, 32)     1056        conv1d_48[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, 32)     0           conv1d_49[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, 32)     0           conv1d_50[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, None, 32)     0           activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, None, 16)     528         multiply_12[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, 16)     0           conv1d_48[0][0]
#                                                                  conv1d_51[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, None, 16)     272         add_12[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, None, 32)     1056        conv1d_52[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, None, 32)     1056        conv1d_52[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, 32)     0           conv1d_53[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, 32)     0           conv1d_54[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, None, 32)     0           activation_26[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, None, 16)     528         multiply_13[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, 16)     0           conv1d_52[0][0]
#                                                                  conv1d_55[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, None, 16)     272         add_13[0][0]
# __________________________________________________________________________________________________
# conv1d_57 (Conv1D)              (None, None, 32)     1056        conv1d_56[0][0]
# __________________________________________________________________________________________________
# conv1d_58 (Conv1D)              (None, None, 32)     1056        conv1d_56[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, 32)     0           conv1d_57[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, 32)     0           conv1d_58[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, None, 32)     0           activation_28[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# conv1d_59 (Conv1D)              (None, None, 16)     528         multiply_14[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, None, 16)     0           conv1d_56[0][0]
#                                                                  conv1d_59[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, None, 16)     272         add_14[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, None, 32)     1056        conv1d_60[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, None, 32)     1056        conv1d_60[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, 32)     0           conv1d_61[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, 32)     0           conv1d_62[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, None, 32)     0           activation_30[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, None, 16)     528         multiply_15[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, None, 16)     0           conv1d_3[0][0]
#                                                                  conv1d_7[0][0]
#                                                                  conv1d_11[0][0]
#                                                                  conv1d_15[0][0]
#                                                                  conv1d_19[0][0]
#                                                                  conv1d_23[0][0]
#                                                                  conv1d_27[0][0]
#                                                                  conv1d_31[0][0]
#                                                                  conv1d_35[0][0]
#                                                                  conv1d_39[0][0]
#                                                                  conv1d_43[0][0]
#                                                                  conv1d_47[0][0]
#                                                                  conv1d_51[0][0]
#                                                                  conv1d_55[0][0]
#                                                                  conv1d_59[0][0]
#                                                                  conv1d_63[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, 16)     0           add_16[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, None, 128)    2176        activation_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, 128)    0           conv1d_64[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, 128)    0           activation_33[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, None, 1)      129         dropout[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, None, 1)      0           conv1d_65[0][0]
# ==================================================================================================
# Total params: 50,465
# Trainable params: 50,465
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
callback_list = [
#         EarlyStopping(
#             monitor="val_loss",
#             patience=2,
#             mode="min"
#         )
]
history = model.fit_generator(generator=train_generator,
                              callbacks=callback_list,
                              epochs=100,
                              validation_data=val_generator)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 12 steps, validate for 4 steps
# Epoch 1/100
# 12/12 [==============================] - 21s 2s/step - loss: 0.7392 - val_loss: 0.6940
# Epoch 2/100
# 12/12 [==============================] - 11s 941ms/step - loss: 0.6888 - val_loss: 0.6503
# Epoch 3/100
# 12/12 [==============================] - 11s 946ms/step - loss: 0.6495 - val_loss: 0.6102
# Epoch 4/100
# 12/12 [==============================] - 11s 951ms/step - loss: 0.6087 - val_loss: 0.5773
# Epoch 5/100
# 12/12 [==============================] - 11s 943ms/step - loss: 0.5836 - val_loss: 0.5600
# Epoch 6/100
# 12/12 [==============================] - 12s 959ms/step - loss: 0.5697 - val_loss: 0.5498
# Epoch 7/100
# 12/12 [==============================] - 11s 941ms/step - loss: 0.5590 - val_loss: 0.5417
# Epoch 8/100
# 12/12 [==============================] - 11s 950ms/step - loss: 0.5498 - val_loss: 0.5337
# Epoch 9/100
# 12/12 [==============================] - 11s 939ms/step - loss: 0.5424 - val_loss: 0.5273
# Epoch 10/100
# 12/12 [==============================] - 11s 940ms/step - loss: 0.5352 - val_loss: 0.5218
# Epoch 11/100
# 12/12 [==============================] - 11s 939ms/step - loss: 0.5294 - val_loss: 0.5169
# Epoch 12/100
# 12/12 [==============================] - 11s 937ms/step - loss: 0.5231 - val_loss: 0.5120
# Epoch 13/100
# 12/12 [==============================] - 11s 947ms/step - loss: 0.5179 - val_loss: 0.5084
# Epoch 14/100
# 12/12 [==============================] - 11s 940ms/step - loss: 0.5139 - val_loss: 0.5055
# Epoch 15/100
# 12/12 [==============================] - 12s 962ms/step - loss: 0.5113 - val_loss: 0.5032
# Epoch 16/100
# 12/12 [==============================] - 11s 940ms/step - loss: 0.5084 - val_loss: 0.5018
# Epoch 17/100
# 12/12 [==============================] - 11s 938ms/step - loss: 0.5055 - val_loss: 0.4992
# Epoch 18/100
# 12/12 [==============================] - 11s 937ms/step - loss: 0.5034 - val_loss: 0.4975
# Epoch 19/100
# 12/12 [==============================] - 11s 948ms/step - loss: 0.5012 - val_loss: 0.4946
# Epoch 20/100
# 12/12 [==============================] - 13s 1s/step - loss: 0.4992 - val_loss: 0.4932
# Epoch 21/100
# 12/12 [==============================] - 14s 1s/step - loss: 0.4975 - val_loss: 0.4919
# Epoch 22/100
# 12/12 [==============================] - 14s 1s/step - loss: 0.4963 - val_loss: 0.4919
# Epoch 23/100
# 12/12 [==============================] - 14s 1s/step - loss: 0.4950 - val_loss: 0.4902
# Epoch 24/100
# 12/12 [==============================] - 14s 1s/step - loss: 0.4936 - val_loss: 0.4889
# Epoch 25/100
# 12/12 [==============================] - 14s 1s/step - loss: 0.4929 - val_loss: 0.4880
# Epoch 26/100
# 12/12 [==============================] - 13s 1s/step - loss: 0.4923 - val_loss: 0.4879
# Epoch 27/100
# 12/12 [==============================] - 14s 1s/step - loss: 0.4913 - val_loss: 0.4883
# Epoch 28/100
# 12/12 [==============================] - 13s 1s/step - loss: 0.4906 - val_loss: 0.4860
# Epoch 29/100
# 12/12 [==============================] - 14s 1s/step - loss: 0.4898 - val_loss: 0.4857
# Epoch 30/100
# 12/12 [==============================] - 13s 1s/step - loss: 0.4891 - val_loss: 0.4859
# Epoch 31/100
# 12/12 [==============================] - 11s 939ms/step - loss: 0.4881 - val_loss: 0.4848
# Epoch 32/100
# 12/12 [==============================] - 11s 951ms/step - loss: 0.4878 - val_loss: 0.4844
# Epoch 33/100
# 12/12 [==============================] - 12s 961ms/step - loss: 0.4875 - val_loss: 0.4841
# Epoch 34/100
# 12/12 [==============================] - 11s 945ms/step - loss: 0.4872 - val_loss: 0.4842
# Epoch 35/100
# 12/12 [==============================] - 11s 936ms/step - loss: 0.4871 - val_loss: 0.4836
# Epoch 36/100
# 12/12 [==============================] - 11s 935ms/step - loss: 0.4857 - val_loss: 0.4827
# Epoch 37/100
# 12/12 [==============================] - 11s 937ms/step - loss: 0.4855 - val_loss: 0.4827
# Epoch 38/100
# 12/12 [==============================] - 11s 937ms/step - loss: 0.4856 - val_loss: 0.4826
# Epoch 39/100
# 12/12 [==============================] - 11s 956ms/step - loss: 0.4853 - val_loss: 0.4828
# Epoch 40/100
# 12/12 [==============================] - 12s 968ms/step - loss: 0.4850 - val_loss: 0.4827
# Epoch 41/100
# 12/12 [==============================] - 11s 940ms/step - loss: 0.4849 - val_loss: 0.4814
# Epoch 42/100
# 12/12 [==============================] - 11s 938ms/step - loss: 0.4841 - val_loss: 0.4814
# Epoch 43/100
# 12/12 [==============================] - 11s 937ms/step - loss: 0.4840 - val_loss: 0.4812
# Epoch 44/100
# 12/12 [==============================] - 11s 946ms/step - loss: 0.4837 - val_loss: 0.4815
# Epoch 45/100
# 12/12 [==============================] - 11s 941ms/step - loss: 0.4832 - val_loss: 0.4811
# Epoch 46/100
# 12/12 [==============================] - 12s 961ms/step - loss: 0.4836 - val_loss: 0.4816
# Epoch 47/100
# 12/12 [==============================] - 11s 952ms/step - loss: 0.4835 - val_loss: 0.4810
# Epoch 48/100
# 12/12 [==============================] - 11s 938ms/step - loss: 0.4829 - val_loss: 0.4807
# Epoch 49/100
# 12/12 [==============================] - 11s 938ms/step - loss: 0.4822 - val_loss: 0.4803
# Epoch 50/100
# 12/12 [==============================] - 11s 944ms/step - loss: 0.4824 - val_loss: 0.4811
# Epoch 51/100
# 12/12 [==============================] - 11s 940ms/step - loss: 0.4825 - val_loss: 0.4808
# Epoch 52/100
# 12/12 [==============================] - 11s 937ms/step - loss: 0.4820 - val_loss: 0.4800
# Epoch 53/100
# 12/12 [==============================] - 12s 975ms/step - loss: 0.4816 - val_loss: 0.4800
# Epoch 54/100
# 12/12 [==============================] - 11s 952ms/step - loss: 0.4817 - val_loss: 0.4802
# Epoch 55/100
# 12/12 [==============================] - 11s 946ms/step - loss: 0.4820 - val_loss: 0.4802
# Epoch 56/100
# 12/12 [==============================] - 11s 936ms/step - loss: 0.4812 - val_loss: 0.4800
# Epoch 57/100
# 12/12 [==============================] - 11s 938ms/step - loss: 0.4814 - val_loss: 0.4804
# Epoch 58/100
# 12/12 [==============================] - 11s 942ms/step - loss: 0.4808 - val_loss: 0.4801
# Epoch 59/100
# 12/12 [==============================] - 11s 937ms/step - loss: 0.4812 - val_loss: 0.4802
# Epoch 60/100
# 12/12 [==============================] - 11s 948ms/step - loss: 0.4806 - val_loss: 0.4799
# Epoch 61/100
# 12/12 [==============================] - 11s 944ms/step - loss: 0.4804 - val_loss: 0.4796
# Epoch 62/100
# 12/12 [==============================] - 11s 946ms/step - loss: 0.4805 - val_loss: 0.4802
# Epoch 63/100
# 12/12 [==============================] - 11s 938ms/step - loss: 0.4803 - val_loss: 0.4804
# Epoch 64/100
# 12/12 [==============================] - 11s 938ms/step - loss: 0.4802 - val_loss: 0.4800
# Epoch 65/100
# 12/12 [==============================] - 11s 946ms/step - loss: 0.4803 - val_loss: 0.4799
# Epoch 66/100
# 12/12 [==============================] - 11s 943ms/step - loss: 0.4803 - val_loss: 0.4803
# Epoch 67/100
# 12/12 [==============================] - 11s 949ms/step - loss: 0.4799 - val_loss: 0.4804
# Epoch 68/100
# 12/12 [==============================] - 11s 938ms/step - loss: 0.4799 - val_loss: 0.4809
# Epoch 69/100
# 12/12 [==============================] - 11s 940ms/step - loss: 0.4799 - val_loss: 0.4799
# Epoch 70/100
# 12/12 [==============================] - 11s 938ms/step - loss: 0.4794 - val_loss: 0.4796
# Epoch 71/100
# 12/12 [==============================] - 11s 936ms/step - loss: 0.4791 - val_loss: 0.4794
# Epoch 72/100
# 12/12 [==============================] - 11s 944ms/step - loss: 0.4791 - val_loss: 0.4799
# Epoch 73/100
# 12/12 [==============================] - 11s 941ms/step - loss: 0.4791 - val_loss: 0.4804
# Epoch 74/100
# 12/12 [==============================] - 11s 956ms/step - loss: 0.4793 - val_loss: 0.4799
# Epoch 75/100
# 12/12 [==============================] - 11s 941ms/step - loss: 0.4789 - val_loss: 0.4812
# Epoch 76/100
# 12/12 [==============================] - 11s 944ms/step - loss: 0.4789 - val_loss: 0.4803
# Epoch 77/100
# 12/12 [==============================] - 11s 940ms/step - loss: 0.4787 - val_loss: 0.4795
# Epoch 78/100
# 12/12 [==============================] - 11s 936ms/step - loss: 0.4788 - val_loss: 0.4799
# Epoch 79/100
# 12/12 [==============================] - 11s 944ms/step - loss: 0.4787 - val_loss: 0.4802
# Epoch 80/100
# 12/12 [==============================] - 11s 942ms/step - loss: 0.4786 - val_loss: 0.4803
# Epoch 81/100
# 12/12 [==============================] - 11s 957ms/step - loss: 0.4790 - val_loss: 0.4799
# Epoch 82/100
# 12/12 [==============================] - 11s 952ms/step - loss: 0.4784 - val_loss: 0.4800
# Epoch 83/100
# 12/12 [==============================] - 11s 937ms/step - loss: 0.4783 - val_loss: 0.4796
# Epoch 84/100
# 12/12 [==============================] - 11s 939ms/step - loss: 0.4778 - val_loss: 0.4800
# Epoch 85/100
# 12/12 [==============================] - 11s 945ms/step - loss: 0.4775 - val_loss: 0.4810
# Epoch 86/100
# 12/12 [==============================] - 11s 938ms/step - loss: 0.4784 - val_loss: 0.4808
# Epoch 87/100
# 12/12 [==============================] - 11s 941ms/step - loss: 0.4780 - val_loss: 0.4813
# Epoch 88/100
# 12/12 [==============================] - 11s 940ms/step - loss: 0.4782 - val_loss: 0.4812
# Epoch 89/100
# 12/12 [==============================] - 11s 944ms/step - loss: 0.4773 - val_loss: 0.4798
# Epoch 90/100
# 12/12 [==============================] - 11s 940ms/step - loss: 0.4772 - val_loss: 0.4810
# Epoch 91/100
# 12/12 [==============================] - 11s 944ms/step - loss: 0.4775 - val_loss: 0.4801
# Epoch 92/100
# 12/12 [==============================] - 11s 938ms/step - loss: 0.4770 - val_loss: 0.4800
# Epoch 93/100
# 12/12 [==============================] - 11s 940ms/step - loss: 0.4768 - val_loss: 0.4808
# Epoch 94/100
# 12/12 [==============================] - 11s 941ms/step - loss: 0.4772 - val_loss: 0.4801
# Epoch 95/100
# 12/12 [==============================] - 11s 938ms/step - loss: 0.4768 - val_loss: 0.4812
# Epoch 96/100
# 12/12 [==============================] - 11s 941ms/step - loss: 0.4766 - val_loss: 0.4802
# Epoch 97/100
# 12/12 [==============================] - 11s 949ms/step - loss: 0.4767 - val_loss: 0.4807
# Epoch 98/100
# 12/12 [==============================] - 12s 970ms/step - loss: 0.4767 - val_loss: 0.4806
# Epoch 99/100
# 12/12 [==============================] - 11s 942ms/step - loss: 0.4761 - val_loss: 0.4801
# Epoch 100/100
# 12/12 [==============================] - 11s 936ms/step - loss: 0.4759 - val_loss: 0.4803

# %%
# serialize model to JSON
model_json = model.to_json()
with open(f"{file_name}.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights(f"{file_name}.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-94c26d94aeab> in <module>
#       1 # serialize model to JSON
# ----> 2 model_json = model.to_json()
#       3 with open(f"{file_name}.json", "w") as json_file:
#       4     json_file.write(model_json)
#       5 model.save_weights(f"{file_name}.h5")
#
# NameError: name 'model' is not defined

# %%
file_name = "models/wavenet_m2o_model"
# load json and create model
json_file = open(f'{file_name}.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights(f"{file_name}.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error Loss')
plt.title('Loss Over Time')
plt.legend(['Train','Valid'])

# %%
inf_generator = generators.FGenerator(file_paths=val_paths,
                                        lookback=lookback,
                                        length=pred_length,
                                        delay=0,
                                        batch_size=1024,
                                        sample_period=1,
                                        electrodes=electrodes,
                                        shuffle=False,
                                        teacher_forcing=True,
                                        teacher_forcing_concat=True)

# %%
def predict_sequence_m2o(input_sequence,
                         history_sequence_target,
                         pred_steps,
                         electrode,
                         model):
    lookback = input_sequence.shape[1]
    electrode_count = history_sequence_target.shape[1]
    pred_sequence = np.zeros((pred_steps,)) # initialize output (pred_steps time steps)  
    history_sequence = input_sequence
#     print(history_sequence.shape)
    history_sequence_target = np.array([history_sequence_target])
#     print(history_sequence_target.shape)

    for i in range(pred_steps):
        # record next time step prediction (last time step of model output) 
        last_step_pred = model.predict(history_sequence)
#         last_step_pred = last_step_pred.reshape(-1)
        
        pred_sequence[i] = last_step_pred[:, -1, :]
#         print(pred_sequence.shape)
        history_sequence_target[0, i, electrode] = pred_sequence[i]
#         print(history_sequence_target.shape)
#         print(history_sequence_target[:, i, electrode].shape)
#         print(history_sequence_target[:, i, :].shape)
        
        # add the next time step prediction to the history sequence
        history_sequence = np.concatenate([history_sequence[:, -(lookback-1):, :], 
                                           history_sequence_target[:, i, :].reshape(1, 1, electrode_count)], axis=1)
#     print(len(pred_sequence))
    return pred_sequence

# %%
def predict_and_plot(encoder_input_data, decoder_target_data, inf_target, sample_ix, pred_steps: int,electrode, enc_tail_len=100):
    encode_series = encoder_input_data[sample_ix:sample_ix+1,:,:] 
    history_sequence_target = inf_target[sample_ix, :, :]
    pred_series = predict_sequence_m2o(encode_series,
                                       history_sequence_target,
                                       pred_steps,
                                       electrode,
                                       model)
    encode_series = encode_series.reshape(-1,1)
    pred_series = pred_series.reshape(-1,1)   
    target_series = decoder_target_data[sample_ix,:,:1].reshape(-1,1)
    encode_series_tail = np.concatenate([encode_series[-enc_tail_len:],target_series[:1]])
    x_encode = encode_series_tail.shape[0]
    r, p = pearsonr(pred_series.reshape(-1), target_series.reshape(-1))
    mae = np.mean(np.abs(pred_series.reshape(-1) - target_series.reshape(-1)))
    print(f"Correlation: {r}. P: {p}. Mae: {mae}")
    plt.figure(figsize=(10,6))   
    
    plt.plot(range(1,x_encode+1),encode_series_tail)
    plt.plot(range(x_encode,x_encode+pred_steps),target_series,color='orange')
    plt.plot(range(x_encode,x_encode+pred_steps),pred_series,color='teal',linestyle='--')
    
    plt.title('Encoder Series Tail of Length %d, Target Series, and Predictions' % enc_tail_len)
    plt.legend(['Encoding Series','Target Series','Predictions'])

# %%
val_batch = val_generator[0]
inf_batch = inf_generator[0]

# %%
val_batch[0].shape
# Out:
# (1024, 119, 114)

# %%
predict_and_plot(val_batch[0], val_batch[1], inf_batch[1],electrode=electrode, sample_ix=0, pred_steps=20)
# Out:
# Correlation: 0.21591695743829023. P: 0.36056694490496966. Mae: 0.46578215723765765

# %%
def get_corr_mae(encoder_input_data, decoder_target_data, inf_target,
                 sample_ix, electrode: int,
                 pred_steps: int,
                 enc_tail_len=100, verbose=True):
    encode_series = encoder_input_data[sample_ix:sample_ix+1,:,:] 
    history_sequence_target = inf_target[sample_ix, :, :]
    pred_series = predict_sequence_m2o(encode_series,
                                       history_sequence_target,
                                       pred_steps,
                                       electrode,
                                       model)
    encode_series = encode_series.reshape(-1,1)
    pred_series = pred_series.reshape(-1,1)   
    target_series = decoder_target_data[sample_ix,:,:1].reshape(-1,1)
    encode_series_tail = np.concatenate([encode_series[-enc_tail_len:],target_series[:1]])
    x_encode = encode_series_tail.shape[0]
    r, p = pearsonr(pred_series.reshape(-1), target_series.reshape(-1))
    mae = np.mean(np.abs(pred_series.reshape(-1) - target_series.reshape(-1)))
    if verbose:
        print(f"Correlation: {r}. P: {p}. MAE: {mae}")
    return r, mae

# %%
encoder_input_data = val_batch[0]
encoder_target_data = val_batch[1]

# %%
n_rows = int(encoder_input_data.shape[0]//2)
r_array = np.empty(shape=(n_rows,))
sample_maes = np.empty(shape=(n_rows,))
for sample_ix in range(n_rows):
    print(f"Sample: {sample_ix}/{n_rows}", end="\r")
    r, mae = get_corr_mae(encoder_input_data, encoder_target_data,
                          inf_batch[1],
                          sample_ix=sample_ix, electrode=electrode,
                          pred_steps=20, verbose=False)
    r_array[sample_ix] = r
    sample_maes[sample_ix] = mae
z_mean = np.mean(r_array)
batch_r = np.tanh(z_mean)
batch_mae = np.mean(sample_maes)
print(f"Batch_r: {batch_r}")
print(f"Batch Mae: {batch_mae}")
# Out:
# Batch_r: -0.04206077273609277
# Batch Mae: 0.5368205005302268

# %%
# Plot the distribution of r
import seaborn as sns
sns.distplot(r_array, kde=True, color = 'darkblue',
             kde_kws={'linewidth': 4})

# %%
k = 5
top_k_r = np.abs(r_array).argsort()[:k]
print(top_k_r)
# Out:
# [376 165 394 125 296]

# %%
for i in top_k_r:
    predict_and_plot(val_batch[0], val_batch[1], inf_batch[1], sample_ix=i, electrode=electrode,
                     pred_steps=20)
# Out:
# Correlation: 0.0012678152950074961. P: 0.9957674542320678. Mae: 0.5377796687276399
# Correlation: 0.0018715298643974115. P: 0.9937520111929996. Mae: 0.4574521861083685
# Correlation: 0.003310747431100075. P: 0.9889474905650331. Mae: 0.3539702082164654
# Correlation: -0.004215211443626354. P: 0.9859283078596118. Mae: 0.5486350810380978
# Correlation: -0.006165177265191557. P: 0.9794198238449962. Mae: 0.47037118672985745

# %%
k = 5
top_k_mae = sample_maes.argsort()[:k]
print(top_k_mae)
# Out:
# [110 188 155 212 477]

# %%
for i in top_k_mae:
    predict_and_plot(val_batch[0], val_batch[1], inf_batch[1], sample_ix=i, electrode=electrode,
                     pred_steps=20)
# Out:
# Correlation: 0.351797415818956. P: 0.1282373906949891. Mae: 0.2749433377694611
# Correlation: -0.36614189844566414. P: 0.11235146899982605. Mae: 0.2769155995017206
# Correlation: 0.4269115740640169. P: 0.06048018416584685. Mae: 0.3074334713184189
# Correlation: 0.04029192403387484. P: 0.8660669526852891. Mae: 0.3079420689968901
# Correlation: -0.22692113788869278. P: 0.3359948215296839. Mae: 0.3097678461506705

# %%
def predict_sequence_m2o_window(input_sequence,
                                history_sequence_target,
                                pred_steps,
                                target_electrode,
                                electrodes,
                                model=model,
                                lookback=lookback):
    electrode_count = len(electrodes)
    pred_sequence = np.zeros((pred_steps,)) # initialize output (pred_steps time steps)  
    history_sequence = input_sequence
    history_sequence_target = np.array([history_sequence_target])

#     print(history_sequence.shape)

    for i in range(pred_steps):
        # record next time step prediction (last time step of model output) 
        history_sequence = history_sequence.reshape((1, lookback, len(electrodes)))
#         print(history_sequence.shape)
        last_step_pred = model.predict(history_sequence)
#         last_step_pred = last_step_pred.reshape(-1)
        
        pred_sequence[i] = last_step_pred[:, -1, :]
#         print(pred_sequence.shape)
        history_sequence_target[0, i, electrode] = pred_sequence[i]
#         print(history_sequence_target.shape)
#         print(history_sequence_target[:, i, electrode].shape)
#         print(history_sequence_target[:, i, :].shape)
        
        # add the next time step prediction to the history sequence
        history_sequence = np.concatenate([history_sequence[:, -(lookback-1):, :], 
                                           history_sequence_target[:, i, :].reshape(1, 1, electrode_count)], axis=1)
#     print(len(pred_sequence))
    return pred_sequence

def moving_window_pred_m2o(input_sequence,
                           lookback,
                           pred_steps,
                           electrode_count,
                           electrodes,
                           target_electrode,
                           model):
    # for each window of lookback predict steps and then
    # move window up by pred steps and repeat
    # window = input_sequence[w_start: w_end]
    final_array = np.empty(shape=(input_sequence.shape[0], 1))
    print(final_array.shape)
    w_start = 0
    w_end = w_start + lookback
    final_array[w_start : w_end] = input_sequence[w_start : w_end, target_electrode].reshape(lookback, 1)
    history_sequence_target = input_sequence
    while w_end + pred_steps < input_sequence.shape[0]:
        window_lookback = input_sequence[w_start: w_end, electrodes]
        pred_seq = predict_sequence_m2o_window(window_lookback,
                                               history_sequence_target,
                                               pred_steps,
                                               target_electrode = target_electrode,
                                               electrodes = electrodes,
                                               model=model,
                                               lookback=lookback)
#         print(pred_seq.shape)
        final_array[w_end:w_end+pred_steps] = pred_seq.reshape(pred_steps, 1)
        w_start += pred_steps
        w_end += pred_steps
    return final_array

def get_corr_mae_conv(input_seq,
                      lookback,
                      pred_length,
                      electrode_count,
                      electrodes,
                      target_electrode,
                      model,
                      enc_tail_len=100,
                      verbose=True):
    
    
    print(input_seq.shape)
    input_seq = input_seq[:,[*electrodes]].reshape(input_seq.shape[0], electrode_count)

    predicted_series = moving_window_pred_m2o(input_seq,
                                              lookback = lookback,
                                              pred_steps = pred_length,
                                              target_electrode=target_electrode,
                                              electrodes = electrodes,
                                              electrode_count=electrode_count,
                                              model=model)
    
    input_seq = input_seq[lookback:, target_electrode]
    print(input_seq.shape)
    predicted_series = predicted_series[lookback:,:]

    input_series = input_seq.reshape(-1,1)
    pred_series = predicted_series.reshape(-1,1)   
    
    x_encode = input_series.shape[0]
    print(input_series.shape)
    print(pred_series.shape)
    r, p = pearsonr(pred_series.reshape(-1), input_series.reshape(-1))
    mae = np.mean(np.abs(pred_series.reshape(-1) - input_series.reshape(-1)))
    if verbose:
        print(f"Correlation: {r}. P: {p}. MAE: {mae}")
    plt.figure(figsize=(10,6))   
    plt.plot(range(x_encode),input_series)
    plt.plot(range(x_encode),pred_series,color='orange',linestyle='--')
    plt.legend(['Input Series', 'Predictions'])
    return r, mae

# %%
data = np.load(val_paths[0])

# %%
target_electrode = electrode

# %%
target_electrode
# Out:
# 5

# %%
get_corr_mae_conv(data[:1100,:],
                  lookback,
                  pred_length, electrode_count=len(electrodes),
                  electrodes=electrodes,
                  target_electrode=target_electrode,
                  model=model)
# Out:
# (1100, 114)
# (1100, 1)
# (1000,)
# (1000, 1)
# (1000, 1)
# Correlation: 0.45176453042711934. P: 1.890030469391733e-51. MAE: 0.609933641952705
# (0.45176453042711934, 0.609933641952705)

# %%
def get_corr_mae_conv_step(input_seq,
                      lookback,
                      pred_length,
                      k,
                      electrode_count,
                      electrodes,
                      target_electrode,
                      model,
                      enc_tail_len=100,
                      verbose=True):
    
    
    print(input_seq.shape)
    input_seq = input_seq[:,[*electrodes]].reshape(input_seq.shape[0], electrode_count)

    predicted_series = moving_window_pred_m2o_step(input_seq,
                                                   lookback = lookback,
                                                   pred_steps = pred_length,
                                                   k=k,
                                                   target_electrode=target_electrode,
                                                   electrodes = electrodes,
                                                   electrode_count=electrode_count,
                                                   model=model)
    
    input_seq = input_seq[lookback + k:, target_electrode]
    print(input_seq.shape)

    input_series = input_seq.reshape(-1,1)
    predicted_series = predicted_series[lookback + k:,target_electrode]
    pred_series = predicted_series.reshape(-1,1)   
    
    x_encode = input_series.shape[0]
    print(input_series.shape)
    print(pred_series.shape)
    r, p = pearsonr(pred_series.reshape(-1), input_series.reshape(-1))
    mae = np.mean(np.abs(pred_series.reshape(-1) - input_series.reshape(-1)))
    if verbose:
        print(f"Correlation: {r}. P: {p}. MAE: {mae}")
    plt.figure(figsize=(10,6))   
    plt.plot(range(x_encode),input_series)
    plt.plot(range(x_encode),pred_series,color='orange',linestyle='--')
    plt.legend(['Input Series', 'Predictions'])
    return r, mae

def moving_window_pred_m2o_step(input_sequence,
                                lookback,
                                pred_steps,
                                k,
                                target_electrode,
                                electrodes,
                                electrode_count,
                                model):
    # for each window of lookback predict steps and then
    # move window up by pred steps and repeat
    # window = input_sequence[w_start: w_end]
    
    electrode_count = len(electrodes)
    final_array = np.empty(shape=(input_sequence.shape[0], electrode_count))
    
    w_start = 0
    w_end = w_start + lookback
    final_array[w_start : w_end + k, :] = input_sequence[w_start : w_end + k, :]
    print(final_array.shape)
    full_length = int(len(input_sequence))
    print(full_length)
    i = w_end + k
    while i < full_length:
        window_lookback = np.array([input_sequence[w_start: w_end, [*electrodes]]])
#         print(window_lookback.shape)
        pred_steps = model.predict(window_lookback)
#         print(pred_steps.reshape((20, 1)))
#         print(pred_steps.shape)
        final_array[w_end + k] = pred_steps[:,k,:].reshape((1, 1))
        w_end += 1
        w_start += 1
        i += 1
    return final_array

# %%
get_corr_mae_conv_step(data[:1100,:],
                  lookback,
                  pred_length, 0,electrode_count=len(electrodes),
                  electrodes=electrodes,
                  target_electrode=target_electrode,
                  model=model)
# Out:
# (1100, 114)
# (1100, 114)
# 1100
# (1000,)
# (1000, 1)
# (1000, 1)
# Correlation: 0.3780469154765683. P: 2.511578490806949e-35. MAE: 0.6413543345569963
# (0.3780469154765683, 0.6413543345569963)

# %%
get_corr_mae_conv_step(data[:1100,:],
                  lookback,
                  pred_length, 5,electrode_count=len(electrodes),
                  electrodes=electrodes,
                  target_electrode=target_electrode,
                  model=model)
# Out:
# (1100, 114)
# (1100, 114)
# 1100
# (995,)
# (995, 1)
# (995, 1)
# Correlation: 0.3788216920550044. P: 2.630346986511845e-35. MAE: 0.6420109542224257
# (0.3788216920550044, 0.6420109542224257)

# %% [markdown]
# TEST DATA

# %% [markdown]
# # TEST DATA

# %%
test_paths = utils.get_file_paths("/home/tmarcu/brain2brain/brain2brain/test_676_bin_norm_2.txt")

# %%
test_paths[0]
# Out:
# '/projects/HASSON/247/data/binned_conversations/676_bin_norm_2/bin_norm_2_NY676_618_Part5-one_conversation1/bin_norm_2_NY676_618_Part5-one_conversation1.npy'

# %%
for path in test_paths:
    utils.get_file_shape(path)
# Out:
# (163846, 114)
# (102096, 114)
# (73475, 114)
# (33158, 114)
# (17795, 114)
# (64950, 114)
# (92170, 114)
# (83951, 114)
# (42936, 114)
# (21311, 114)

# %%
test_data = np.load(test_paths[0])

# %%
get_corr_mae_conv(test_data[300:1400,:],
                  lookback,
                  pred_length, electrode_count=len(electrodes),
                  electrodes=electrodes,
                  target_electrode=target_electrode,
                  model=model)
# Out:
# (1100, 114)
# (1100, 1)
# (1000,)
# (1000, 1)
# (1000, 1)
# Correlation: 0.25832158428656327. P: 1.0419958245039133e-16. MAE: 0.6840802865851197
# (0.25832158428656327, 0.6840802865851197)

# %%
get_corr_mae_conv(test_data[250:600,:],
                  lookback,
                  pred_length, electrode_count=len(electrodes),
                  electrodes=electrodes,
                  target_electrode=target_electrode,
                  model=model)
# Out:
# (350, 114)
# (350, 1)
# (250,)
# (250, 1)
# (250, 1)
# Correlation: 0.23771651222740345. P: 0.0001480458839169156. MAE: 0.6862982383436043
# (0.23771651222740345, 0.6862982383436043)

# %%
get_corr_mae_conv(test_data[:1100,:],
                  lookback,
                  pred_length, electrode_count=len(electrodes),
                  electrodes=electrodes,
                  target_electrode=target_electrode,
                  model=model)
# Out:
# (1100, 114)
# (1100, 1)

# %%
get_corr_mae_conv_step(test_data[:300,:],
                  lookback,
                  pred_length, 0,electrode_count=len(electrodes),
                  electrodes=electrodes,
                  target_electrode=target_electrode,
                  model=model)

# %%
get_corr_mae_conv_step(test_data[:1100,:],
                  lookback,
                  pred_length, 0,electrode_count=len(electrodes),
                  electrodes=electrodes,
                  target_electrode=target_electrode,
                  model=model)

# %%
get_corr_mae_conv_step(test_data[:1100,:],
                  lookback,
                  pred_length, 5,electrode_count=len(electrodes),
                  electrodes=electrodes,
                  target_electrode=target_electrode,
                  model=model)

# %%
get_corr_mae_conv_step(test_data[:1100,:],
                  lookback,
                  pred_length, 10,electrode_count=len(electrodes),
                  electrodes=electrodes,
                  target_electrode=target_electrode,
                  model=model)

# %%
# Test_gene
test_generator = generators.FGenerator(file_paths=test_paths,
                                        lookback=lookback,
                                        length=pred_length,
                                        delay=0,
                                        batch_size=2048,
                                        sample_period=1,
                                        electrodes=electrodes,
                                        electrode_output_ix=target_electrode,
                                        shuffle=False)

# %%
len(test_generator)
# Out:
# 2

# %%
test_batch = test_generator[0]

# %%
encoder_input_data = test_batch[0]
encoder_target_data = test_batch[1]

# %%
n_rows = int(encoder_input_data.shape[0]//2)
r_array = np.empty(shape=(n_rows,))
sample_maes = np.empty(shape=(n_rows,))
for sample_ix in range(n_rows):
    print(f"Sample: {sample_ix}/{n_rows}", end="\r")
    r, mae = get_corr_mae(encoder_input_data, encoder_target_data,
                          inf_batch[1],
                          sample_ix=sample_ix, electrode=electrode,
                          pred_steps=20, verbose=False)
    r_array[sample_ix] = r
    sample_maes[sample_ix] = mae
z_mean = np.mean(r_array)
batch_r = np.tanh(z_mean)
batch_mae = np.mean(sample_maes)
print(f"Batch_r: {batch_r}")
print(f"Batch Mae: {batch_mae}")
# Out:
# Batch_r: 0.07390052069036486
# Batch Mae: 0.6917688861213863
