# %% [markdown]
# # Baseline Neural Network MAE

# %% [markdown]
# ### Focus on Electrode 5

# %%
# Autoreload
# %load_ext autoreload
# %autoreload 2

# %%
# Imports
import numpy as np
import json
import pandas as pd
import numpy as np
import time
import string
from matplotlib import pyplot as plt
import tensorflow as tf
import sys
sys.path.append('../../../')
from brain2brain import utils, generators, models
# %matplotlib inline

# TF
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# TCN
from brain2brain.tcn import TCN
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Flatten, GRU, LSTM, RepeatVector, TimeDistributed
from tensorflow.keras.models import model_from_json

from scipy.stats import pearsonr

from brain2brain import utils, models

# %%
train_paths = utils.get_file_paths("/home/tmarcu/brain2brain/brain2brain/train_676_bin_norm_2.txt")
val_paths = utils.get_file_paths("/home/tmarcu/brain2brain/brain2brain/val_676_bin_norm_2.txt")
total_electrode_count = utils.get_file_shape(train_paths[0])[1]
# Electrodes
electrode_count = 114
electrodes = range(114)
electrode = 5
lookback = 50
pred_length = 10
# Training Generator
train_generator = generators.FGenerator(file_paths=train_paths,
                                        lookback=lookback,
                                        length=pred_length,
                                        delay=0,
                                        batch_size=1024,
                                        sample_period=1,
                                        electrodes=electrodes,
                                        electrode_output_ix=electrode,
                                        shuffle=True)
# Validation Generator
val_generator = generators.FGenerator(file_paths=val_paths,
                                        lookback=lookback,
                                        length=pred_length,
                                        delay=0,
                                        batch_size=1024,
                                        sample_period=1,
                                        electrodes=electrodes,
                                        electrode_output_ix=electrode,
                                        shuffle=False)
# Out:
# (5429, 114)

# %%
train_generator[0][0].shape
# Out:
# (1024, 50, 114)

# %%
train_generator[0][1].shape
# Out:
# (1024, 10, 1)

# %%
hidden_units = 128
output_dim = 10
input_len = 50
model = models.define_baseline_nn_model_m2o(hidden_units,input_len, output_dim, electrode_count)
model.compile(optimizer=Adam(), loss='mae')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 50, 128)           14720
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                64010
# _________________________________________________________________
# reshape (Reshape)            (None, 10, 1)             0
# =================================================================
# Total params: 78,730
# Trainable params: 78,730
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback_list = [
#         EarlyStopping(
#             monitor="val_loss",
#             patience=5,
#             mode="min"
#         )
]
history = model.fit_generator(generator=train_generator,
                              callbacks=callback_list,
                              epochs=25,
                              validation_data=val_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-9-cee8305406b0>:11: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 25 steps, validate for 8 steps
# Epoch 1/25
# 25/25 [==============================] - 17s 665ms/step - loss: 0.9168 - val_loss: 0.7526
# Epoch 2/25
# 25/25 [==============================] - 16s 629ms/step - loss: 0.6794 - val_loss: 0.6669
# Epoch 3/25
# 25/25 [==============================] - 16s 620ms/step - loss: 0.6110 - val_loss: 0.6387
# Epoch 4/25
# 25/25 [==============================] - 15s 615ms/step - loss: 0.5792 - val_loss: 0.6323
# Epoch 5/25
# 25/25 [==============================] - 16s 624ms/step - loss: 0.5665 - val_loss: 0.6268
# Epoch 6/25
# 25/25 [==============================] - 16s 622ms/step - loss: 0.5576 - val_loss: 0.6250
# Epoch 7/25
# 25/25 [==============================] - 15s 618ms/step - loss: 0.5521 - val_loss: 0.6251
# Epoch 8/25
# 25/25 [==============================] - 16s 625ms/step - loss: 0.5502 - val_loss: 0.6255
# Epoch 9/25
# 25/25 [==============================] - 15s 618ms/step - loss: 0.5444 - val_loss: 0.6278
# Epoch 10/25
# 25/25 [==============================] - 16s 624ms/step - loss: 0.5397 - val_loss: 0.6274
# Epoch 11/25
# 25/25 [==============================] - 16s 621ms/step - loss: 0.5394 - val_loss: 0.6309
# Epoch 12/25
# 25/25 [==============================] - 11s 439ms/step - loss: 0.5374 - val_loss: 0.6308
# Epoch 13/25
# 25/25 [==============================] - 8s 335ms/step - loss: 0.5361 - val_loss: 0.6308
# Epoch 14/25
# 25/25 [==============================] - 9s 348ms/step - loss: 0.5305 - val_loss: 0.6326
# Epoch 15/25
# 25/25 [==============================] - 9s 341ms/step - loss: 0.5283 - val_loss: 0.6326
# Epoch 16/25
# 25/25 [==============================] - 8s 331ms/step - loss: 0.5294 - val_loss: 0.6335
# Epoch 17/25
# 25/25 [==============================] - 8s 332ms/step - loss: 0.5296 - val_loss: 0.6342
# Epoch 18/25
# 25/25 [==============================] - 8s 331ms/step - loss: 0.5246 - val_loss: 0.6349
# Epoch 19/25
# 25/25 [==============================] - 8s 333ms/step - loss: 0.5239 - val_loss: 0.6382
# Epoch 20/25
# 25/25 [==============================] - 8s 331ms/step - loss: 0.5246 - val_loss: 0.6380
# Epoch 21/25
# 25/25 [==============================] - 8s 332ms/step - loss: 0.5230 - val_loss: 0.6371
# Epoch 22/25
# 25/25 [==============================] - 8s 333ms/step - loss: 0.5215 - val_loss: 0.6383
# Epoch 23/25
# 25/25 [==============================] - 8s 337ms/step - loss: 0.5192 - val_loss: 0.6388
# Epoch 24/25
# 25/25 [==============================] - 9s 341ms/step - loss: 0.5221 - val_loss: 0.6421
# Epoch 25/25
# 25/25 [==============================] - 8s 333ms/step - loss: 0.5195 - val_loss: 0.6417

# %%
# serialize model to JSON
model_json = model.to_json()
with open("models/baseline_2_nn_m2o_model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("models/baseline_2_nn_m2o_model.h5")

# %%
# load json and create model
json_file = open('models/baseline_2_nn_m2o_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights("models/baseline_2_nn_m2o_model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error Loss')
plt.title('Loss Over Time')
plt.legend(['Train','Valid'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b6fe65cffa51> in <module>
# ----> 1 plt.plot(history.history['loss'])
#       2 plt.plot(history.history['val_loss'])
#       3
#       4 plt.xlabel('Epoch')
#       5 plt.ylabel('Mean Absolute Error Loss')
#
# NameError: name 'history' is not defined

# %%
val_generator[0][1].shape
# Out:
# (1024, 10, 1)

# %%
inf_generator = generators.FGenerator(file_paths=val_paths,
                                        lookback=lookback,
                                        length=pred_length,
                                        delay=0,
                                        batch_size=1024,
                                        sample_period=1,
                                        electrodes=electrodes,
                                        shuffle=False)

# %%
def predict_sequence_m2o(input_sequence,
                         history_sequence_target,
                         pred_steps,
                         electrode,
                         model):
    lookback = input_sequence.shape[0]
    electrode_count = history_sequence_target.shape[1]
    pred_sequence = np.zeros((pred_steps,)) # initialize output (pred_steps time steps)  
    history_sequence = np.array([input_sequence])
    history_sequence_target = np.array([history_sequence_target])

    for i in range(pred_steps):
        last_step_pred = model.predict(history_sequence)  
        pred_sequence[i] = last_step_pred[:, -1, :]

        history_sequence_target[0, i, electrode] = pred_sequence[i]
        history_sequence = np.concatenate([history_sequence[:, -(lookback-1):, :], 
                                           history_sequence_target[:, i, :].reshape(1, 1, electrode_count)], axis=1)
    return pred_sequence

# %%
# predict_sequence_m2o(val_generator[0][0][, inf_generator[0][1][0], 20, electrode, model)

# %%
def predict_and_plot(model,
                     input_sequnece_batch,
                     target_sequence_batch,
                     inf_target,
                     electrode,
                     sample_ix,
                     pred_steps: int,
                     enc_tail_len=50):
    input_sequence = input_sequnece_batch[sample_ix]
    target_sequence = target_sequence_batch[sample_ix]
    history_sequence_target = inf_target[sample_ix, :, :]
    pred_series = predict_sequence_m2o(input_sequence,
                                        history_sequence_target,
                                        pred_steps, electrode, model)
    input_sequence = input_sequence.reshape(-1,1)
    pred_series = pred_series.reshape(-1,1)   
    target_sequnece = target_sequence.reshape(pred_steps,1)
    print(target_sequence.shape)
    input_sequence_tail = np.concatenate([input_sequence[-enc_tail_len:],target_sequence[:1]])
    x_encode = input_sequence_tail.shape[0]
    
    r, p = pearsonr(pred_series.reshape(-1), target_sequence.reshape(-1))
    mae = np.mean(np.abs(pred_series.reshape(-1) - target_sequence.reshape(-1)))
    print(f"Correlation: {r}. P: {p}. MAE: {mae}")
    plt.figure(figsize=(10,6))   
    
    plt.plot(range(1,x_encode+1), input_sequence_tail)
    plt.plot(range(x_encode,x_encode+pred_steps),target_sequence,color='orange')
    plt.plot(range(x_encode,x_encode+pred_steps),pred_series,color='teal',linestyle='--')
    
    plt.title('Encoder Series Tail of Length %d, Target Series, and Predictions' % enc_tail_len)
    plt.legend(['Encoding Series','Target Series','Predictions'])

# %%
predict_and_plot(model, val_generator[0][0], val_generator[0][1], 
                 inf_generator[0][1], electrode,
                 0, pred_steps = 10)
# Out:
# (10, 1)
# Correlation: -0.1782573316878235. P: 0.6222181843813342. MAE: 0.6759895697371026

# %%
predict_and_plot(model, val_generator[0][0], val_generator[0][1], 
                 inf_generator[0][1], electrode,
                 1, pred_steps = 10)
# Out:
# (10, 1)
# Correlation: 0.0806654286986503. P: 0.8246880801163158. MAE: 0.6498040726578777

# %%
def get_corr_mae(model,
                     input_sequnece_batch,
                     target_sequence_batch,
                     inf_target,
                     electrode,
                     sample_ix,
                     pred_steps: int,
                     enc_tail_len=50,
                    verbose=True):
    input_sequence = input_sequnece_batch[sample_ix]
    target_sequence = target_sequence_batch[sample_ix]
    history_sequence_target = inf_target[sample_ix, :, :]
    pred_series = predict_sequence_m2o(input_sequence,
                                        history_sequence_target,
                                        pred_steps, electrode, model)
    input_sequence = input_sequence.reshape(-1,1)
    pred_series = pred_series.reshape(-1,1)   
    target_sequnece = target_sequence.reshape(pred_steps,1)
    input_sequence_tail = np.concatenate([input_sequence[-enc_tail_len:],target_sequence[:1]])
    x_encode = input_sequence_tail.shape[0]
    
    r, p = pearsonr(pred_series.reshape(-1), target_sequence.reshape(-1))
    mae = np.mean(np.abs(pred_series.reshape(-1) - target_sequence.reshape(-1)))
    if verbose:
        print(f"Correlation: {r}. P: {p}. MAE: {mae}")
    return r, mae

# %%
get_corr_mae(model, val_generator[0][0], val_generator[0][1], inf_generator[0][1],
             electrode, 1, pred_steps = 10)
# Out:
# Correlation: 0.0806654286986503. P: 0.8246880801163158. MAE: 0.6498040726578777
# (0.0806654286986503, 0.6498040726578777)

# %%
print("Calculating MAE/CORR per batch.")
batch_ix = 0
val_batch = val_generator[batch_ix] 
n_rows = int(val_batch[0].shape[0]//2)
r_array = np.empty(shape=(n_rows,))
z_array = np.empty(shape=(n_rows,))

sample_maes = np.empty(shape=(n_rows,))
for sample_ix in range(n_rows):
    print(f"Sample: {sample_ix}/{n_rows}", end="\r")
    r, mae = get_corr_mae(model, val_batch[0], val_batch[1],inf_generator[0][1],
                              electrode,
                                sample_ix=sample_ix, pred_steps=10, verbose=False)
    r_array[sample_ix] = r
    z_array[sample_ix] = 0.5 * np.log((1 + r)/(1-r))
    sample_maes[sample_ix] = mae
z_mean = np.mean(z_array)
batch_r = (np.exp(2 * z_mean) - 1)/(np.exp(2 * z_mean) + 1)
batch_mae = np.mean(sample_maes)
print(f"Batch_r: {batch_r}")
print(f"Absolute Batch_r: {np.mean(np.abs(r_array))}")
print(f"Batch Mae: {batch_mae}")
# Out:
#   File "<ipython-input-15-80c157825526>", line 26
#     sns.distplot(, kde=True,
#                  ^
# SyntaxError: invalid syntax

# %%
print("Calculating MAE/CORR per batch.")
batch_ix = 0
val_batch = val_generator[batch_ix] 
n_rows = int(val_batch[0].shape[0]//2)
r_array = np.empty(shape=(n_rows,))
z_array = np.empty(shape=(n_rows,))

sample_maes = np.empty(shape=(n_rows,))
for sample_ix in range(n_rows):
    print(f"Sample: {sample_ix}/{n_rows}", end="\r")
    r, mae = get_corr_mae(model, val_batch[0], val_batch[1],inf_generator[0][1],
                              electrode,
                                sample_ix=sample_ix, pred_steps=10, verbose=False)
    r_array[sample_ix] = r
    z_array[sample_ix] = 0.5 * np.log((1 + r)/(1-r))
    sample_maes[sample_ix] = mae
z_mean = np.mean(z_array)
batch_r = (np.exp(2 * z_mean) - 1)/(np.exp(2 * z_mean) + 1)
batch_mae = np.mean(sample_maes)
print(f"Batch_r: {batch_r}")
print(f"Absolute Batch_r: {np.mean(np.abs(r_array))}")
print(f"Batch Mae: {batch_mae}")
# Out:
# Calculating MAE/CORR per batch.
# Batch_r: 0.022965751512889165
# Absolute Batch_r: 0.28071737713704165
# Batch Mae: 0.630903092950511

# %%
# Plot the distribution of r
import seaborn as sns
sns.distplot(r_array, kde=True, color = 'darkblue',
             kde_kws={'linewidth': 4})

# %%
k = 5
top_k_r = np.abs(r_array).argsort()[-k:]
print(top_k_r)
# Out:
# [483 226 409 375 367]

# %%
for i in top_k_r:
    predict_and_plot(model, val_batch[0], val_batch[1], inf_generator[0][1], 
                     electrode, sample_ix=i,
                     pred_steps=10)
# Out:
# (10, 1)
# Correlation: 0.7942085637473684. P: 0.006070232010694755. MAE: 0.616132854273035
# (10, 1)
# Correlation: -0.8038103486397004. P: 0.0050768986114894535. MAE: 0.7569801275816599
# (10, 1)
# Correlation: -0.8226985548975757. P: 0.0034697933874150476. MAE: 0.8320157017600718
# (10, 1)
# Correlation: 0.8314224240260466. P: 0.0028675127398644926. MAE: 0.30730428516903324
# (10, 1)
# Correlation: 0.8334849864208611. P: 0.002736934517024906. MAE: 0.6141214021278112

# %%
k = 5
top_k_mae = sample_maes.argsort()[:k]
print(top_k_mae)
# Out:
# [ 88 311 364 221 324]

# %%
for i in top_k_mae:
    predict_and_plot(model, val_batch[0], val_batch[1], inf_generator[0][1], 
                     electrode, sample_ix=i,
                     pred_steps=10)
# Out:
# (10, 1)
# Correlation: 0.7385406079976888. P: 0.014703342337398739. MAE: 0.233557599836345
# (10, 1)
# Correlation: 0.34690740441677603. P: 0.3260595339485268. MAE: 0.258372440498405
# (10, 1)
# Correlation: 0.4804275260753649. P: 0.1598856180696723. MAE: 0.27956667666050417
# (10, 1)
# Correlation: 0.002030381089193456. P: 0.9955585596770231. MAE: 0.2899087169077678
# (10, 1)
# Correlation: 0.6096061785163336. P: 0.061327253880082665. MAE: 0.29195030091612395

# %%
def predict_sequence_m2o_window(input_sequence,
                                history_sequence_target,
                                pred_steps,
                                target_electrode,
                                electrodes,
                                model=model,
                                lookback=lookback):
    electrode_count = len(electrodes)
    pred_sequence = np.zeros((pred_steps,)) # initialize output (pred_steps time steps)  
    history_sequence = input_sequence
    history_sequence_target = np.array([history_sequence_target])

#     print(history_sequence.shape)

    for i in range(pred_steps):
        # record next time step prediction (last time step of model output) 
        history_sequence = history_sequence.reshape((1, lookback, len(electrodes)))
#         print(history_sequence.shape)
        last_step_pred = model.predict(history_sequence)
#         last_step_pred = last_step_pred.reshape(-1)
        
        pred_sequence[i] = last_step_pred[:, -1, :]
#         print(pred_sequence.shape)
        history_sequence_target[0, i, electrode] = pred_sequence[i]
#         print(history_sequence_target.shape)
#         print(history_sequence_target[:, i, electrode].shape)
#         print(history_sequence_target[:, i, :].shape)
        
        # add the next time step prediction to the history sequence
        history_sequence = np.concatenate([history_sequence[:, -(lookback-1):, :], 
                                           history_sequence_target[:, i, :].reshape(1, 1, electrode_count)], axis=1)
#     print(len(pred_sequence))
    return pred_sequence

def moving_window_pred_m2o(input_sequence,
                           lookback,
                           pred_steps,
                           electrode_count,
                           electrodes,
                           target_electrode,
                           model):
    # for each window of lookback predict steps and then
    # move window up by pred steps and repeat
    # window = input_sequence[w_start: w_end]
    final_array = np.empty(shape=(input_sequence.shape[0], 1))
    print(final_array.shape)
    w_start = 0
    w_end = w_start + lookback
    final_array[w_start : w_end] = input_sequence[w_start : w_end, target_electrode].reshape(lookback, 1)
    history_sequence_target = input_sequence
    while w_end + pred_steps < input_sequence.shape[0]:
        window_lookback = input_sequence[w_start: w_end, electrodes]
        pred_seq = predict_sequence_m2o_window(window_lookback,
                                               history_sequence_target,
                                               pred_steps,
                                               target_electrode = target_electrode,
                                               electrodes = electrodes,
                                               model=model,
                                               lookback=lookback)
#         print(pred_seq.shape)
        final_array[w_end:w_end+pred_steps] = pred_seq.reshape(pred_steps, 1)
        w_start += pred_steps
        w_end += pred_steps
    return final_array

def get_corr_mae_conv(input_seq,
                      lookback,
                      pred_length,
                      electrode_count,
                      electrodes,
                      target_electrode,
                      model,
                      enc_tail_len=100,
                      verbose=True):
    
    
    print(input_seq.shape)
    input_seq = input_seq[:,[*electrodes]].reshape(input_seq.shape[0], electrode_count)

    predicted_series = moving_window_pred_m2o(input_seq,
                                              lookback = lookback,
                                              pred_steps = pred_length,
                                              target_electrode=target_electrode,
                                              electrodes = electrodes,
                                              electrode_count=electrode_count,
                                              model=model)
    
    input_seq = input_seq[lookback:, target_electrode]
    print(input_seq.shape)
    predicted_series = predicted_series[lookback:,:]

    input_series = input_seq.reshape(-1,1)
    pred_series = predicted_series.reshape(-1,1)   
    
    x_encode = input_series.shape[0]
    print(input_series.shape)
    print(pred_series.shape)
    r, p = pearsonr(pred_series.reshape(-1), input_series.reshape(-1))
    mae = np.mean(np.abs(pred_series.reshape(-1) - input_series.reshape(-1)))
    if verbose:
        print(f"Correlation: {r}. P: {p}. MAE: {mae}")
    plt.figure(figsize=(10,6))   
    plt.plot(range(x_encode),input_series)
    plt.plot(range(x_encode),pred_series,color='orange',linestyle='--')
    plt.legend(['Input Series', 'Predictions'])
    return r, mae

# %%
data = np.load(val_paths[0])

# %%
target_electrode = electrode

# %%
target_electrode
# Out:
# 5

# %%
get_corr_mae_conv(data[:2000,:],
                  lookback,
                  pred_length, electrode_count=len(electrodes),
                  electrodes=electrodes,
                  target_electrode=target_electrode,
                  model=model)
# Out:
# (2000, 114)
# (2000, 1)
# (1950,)
# (1950, 1)
# (1950, 1)
# Correlation: 0.4001547611295532. P: 6.908159399986874e-76. MAE: 0.6657313783012423
# (0.4001547611295532, 0.6657313783012423)

# %%
get_corr_mae_conv(data[:750,:],
                  lookback,
                  pred_length, electrode_count=len(electrodes),
                  electrodes=electrodes,
                  target_electrode=target_electrode,
                  model=model)
# Out:
# (750, 114)
# (750, 1)
# (700,)
# (700, 1)
# (700, 1)
# Correlation: 0.441352463416513. P: 9.873342005319638e-35. MAE: 0.6407902142711381
# (0.441352463416513, 0.6407902142711381)

# %%
get_corr_mae_conv(data[250:500,:],
                  lookback,
                  pred_length, electrode_count=len(electrodes),
                  electrodes=electrodes,
                  target_electrode=target_electrode,
                  model=model)
# Out:
# (250, 114)
# (250, 1)
# (200,)
# (200, 1)
# (200, 1)
# Correlation: 0.14567440413541222. P: 0.0395683988965978. MAE: 0.6213406069300461
# (0.14567440413541222, 0.6213406069300461)
